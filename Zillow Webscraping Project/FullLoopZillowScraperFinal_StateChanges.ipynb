# %% [markdown]
# # <center>Zillow Webscraping Project<center>

# %% [markdown]
# ## Project Details:
# In this project, I will utilize BeautifulSoup to webscrape and collect Zillow housing data from multiple listing pages. The purpose of this project is to collect housing data for every state in the United States. For this project, I will attempt to collect about 600 house listings for each state to have roughly 30,000 house listings combined. 600 house listings from each state will ensure that enough data was collected to perform accurate data analysis.
#
# ## Data Collection and Wrangling:
# I will attempt to collect
# - House Price
# - House Address
# - House Beds, Baths, and SqFt
# - House URL/Link to Zillow
#
# ## Project Goals:
# - Collect 600 house listings per U.S. state using BeautifulSoup Webscraping
# - Perform Exploratory Data Analysis with the housing data
# - Create a dynamic dashboard that can be used to search house listings and analyze housing data in each state
#
# *Note: Because of how the webscraping code is written, it will be ran 50 times for each U.S. state. The 50 dataframes will then be appended to create the final dataframe

# %% [markdown]
# ## Import Needed Python Packages

# %%
# Packages
import pandas as pd
import numpy as np

import requests
import os
import time
import sys
from IPython import display
from IPython.display import Image

import regex as re
import prettify
import numbers
import htmltext

import lxml
from lxml.html.soupparser import fromstring

from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %% [markdown]
# ## BeautifulSoup Webscraping/Data Collection

# %%
# Add headers to keep from getting capthas returns from Zillow
req_headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'en-US,en;q=0.8',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'
}

# %%
# Create variables for all pages of Zillow that will be looped
# About 15 pages will be looped to colelct 600 listings per state (Zillow has about 40 listings per page)

with requests.Session() as s:
    scrapingstate = 'washington dc/' #*--Change to desired state to scrape house listings--*
    
    Page = 'https://www.zillow.com/homes/for_sale/'+scrapingstate
    Page2 = 'https://www.zillow.com/homes/for_sale/'+scrapingstate+'/2_p/'
    Page3 = 'https://www.zillow.com/homes/for_sale/'+scrapingstate+'/3_p/'
    Page4 = 'https://www.zillow.com/homes/for_sale/'+scrapingstate+'/4_p/'
    Page5 = 'https://www.zillow.com/homes/for_sale/'+scrapingstate+'/5_p/'
    Page6 = 'https://www.zillow.com/homes/for_sale/'+scrapingstate+'/6_p/'
    Page7 = 'https://www.zillow.com/homes/for_sale/'+scrapingstate+'/7_p/'
    Page8 = 'https://www.zillow.com/homes/for_sale/'+scrapingstate+'/8_p/'
    Page9 = 'https://www.zillow.com/homes/for_sale/'+scrapingstate+'/9_p/'
    Page10 = 'https://www.zillow.com/homes/for_sale/'+scrapingstate+'/10_p/'
    Page11 = 'https://www.zillow.com/homes/for_sale/'+scrapingstate+'/11_p/'
    Page12 = 'https://www.zillow.com/homes/for_sale/'+scrapingstate+'/12_p/'
    Page13 = 'https://www.zillow.com/homes/for_sale/'+scrapingstate+'/13_p/'
    Page14 = 'https://www.zillow.com/homes/for_sale/'+scrapingstate+'/14_p/'
    Page15 = 'https://www.zillow.com/homes/for_sale/'+scrapingstate+'/15_p/'

    r = s.get(Page, headers=req_headers)
    r2 = s.get(Page2, headers=req_headers)
    r3 = s.get(Page3, headers=req_headers)
    r4 = s.get(Page4, headers=req_headers)
    r5 = s.get(Page5, headers=req_headers)
    r6 = s.get(Page6, headers=req_headers)
    r7 = s.get(Page7, headers=req_headers)
    r8 = s.get(Page8, headers=req_headers)
    r9 = s.get(Page9, headers=req_headers)
    r10 = s.get(Page10, headers=req_headers)
    r11 = s.get(Page11, headers=req_headers)
    r12 = s.get(Page12, headers=req_headers)
    r13 = s.get(Page13, headers=req_headers)
    r14 = s.get(Page14, headers=req_headers)
    r15 = s.get(Page15, headers=req_headers)
    
    url_links = [Page, Page2, Page3, Page4, Page5, Page6, Page7, Page8, Page9, Page10, Page11, Page12, Page13, Page14, Page15]

# %%
# Now add the contents from urls to soup variables of each url
soup = BeautifulSoup(r.content, 'html.parser')
soup1 = BeautifulSoup(r2.content, 'html.parser')
soup2 = BeautifulSoup(r3.content, 'html.parser')
soup3 = BeautifulSoup(r4.content, 'html.parser')
soup4 = BeautifulSoup(r5.content, 'html.parser')
soup5 = BeautifulSoup(r6.content, 'html.parser')
soup6 = BeautifulSoup(r7.content, 'html.parser')
soup7 = BeautifulSoup(r8.content, 'html.parser')
soup8 = BeautifulSoup(r9.content, 'html.parser')
soup9 = BeautifulSoup(r10.content, 'html.parser')
soup10 = BeautifulSoup(r10.content, 'html.parser')
soup11 = BeautifulSoup(r10.content, 'html.parser')
soup12 = BeautifulSoup(r10.content, 'html.parser')
soup13 = BeautifulSoup(r10.content, 'html.parser')
soup14 = BeautifulSoup(r10.content, 'html.parser')

# %% [markdown]
# ### Page 1 Loop

# %%
# Create first datarame for first page of Zillow
df = pd.DataFrame()

# Create loop that pulls each specified variable
for i in soup:
    address = soup.find_all (class_= 'list-card-addr')
    price = list(soup.find_all (class_='list-card-price'))
    details = list(soup.find_all("ul", class_="list-card-details"))    
    
# Create columns for dataframe
df['prices'] = price
df['address'] = address
df['details'] = details

# Create an empty url list
urls = []
# Now Loop through the url and pull the href and strip out the address tag
for link in soup.find_all("article"):
    href = link.find('a',class_="list-card-link")
    addresses = href.find('address')
    addresses.extract()
    urls.append(href)

# %%
# Import the urls into a column called links
df['links'] = urls
df['links'] = df['links'].astype('str')

# %% [markdown]
# ### Page 2 Loop

# %%
# Create the second datarame for second page of Zillow
df1 = pd.DataFrame()

for i in soup1:
    address1 = soup1.find_all (class_= 'list-card-addr')
    price1 = list(soup1.find_all (class_='list-card-price'))
    details1 = list(soup.find_all("ul", class_="list-card-details"))
            

df1['prices'] = price1
df1['address'] = address1
df1['details'] = details1


urls = []

for link in soup1.find_all("article"):
    href = link.find('a',class_="list-card-link")
    addresses = href.find('address')
    addresses.extract()
    urls.append(href)

# %%
# Import the urls into a column called links
df1['links'] = urls
df1['links'] = df1['links'].astype('str')

# %% [markdown]
# ### Append the first two dataframes to ensure that scraping and looping are working

# %%
# Append
df = df.append(df1, ignore_index = True)

# %%
# Show top 5 rows
df.head()
# Out:
#          prices                                            address  \
# 0  [$1,019,000]            [4810 48th St NW, Washington, DC 20016]
# 1  [$1,049,999]               [1323 F St NE, Washington, DC 20002]
# 2    [$395,000]   [1669 Columbia Rd NW #410, Washington, DC 20009]
# 3  [$1,795,000]     [3750 Northampton St NW, Washington, DC 20015]
# 4  [$1,499,000]  [609 Maryland Ave NE UNIT 5, Washington, DC 20...
#
#                                              details  \
# 0  [[3, [ ,  , bds]], [3, [ ,  , ba]], [2,500, [ ...
# 1  [[3, [ ,  , bds]], [3, [ ,  , ba]], [1,515, [ ...
# 2  [[2, [ ,  , bds]], [2, [ ,  , ba]], [1,120, [ ...
# 3  [[4, [ ,  , bds]], [4, [ ,  , ba]], [3,082, [ ...
# 4  [[2, [ ,  , bds]], [3, [ ,  , ba]], [2,634, [ ...
#
#                                                links
# 0  <a class="list-card-link list-card-link-top-ma...
# 1  <a class="list-card-link list-card-link-top-ma...
# 2  <a class="list-card-link list-card-link-top-ma...
# 3  <a class="list-card-link list-card-link-top-ma...
# 4  <a class="list-card-link list-card-link-top-ma...

# %%
# See number of rows collected so far on 2 pages
# *Note: Each page on zillow contains between 35-40 houses
len(df)
# Out:
# 80

# %% [markdown]
# ### Scraping and looping appear to be working with 80 houses collected from page 1 and page 2.

# %%
# Now create the other empty dataframes for each page to keep from having to declare before each loop
df2 = pd.DataFrame()
df3 = pd.DataFrame()
df4 = pd.DataFrame()
df5 = pd.DataFrame()
df6 = pd.DataFrame()
df7 = pd.DataFrame()
df8 = pd.DataFrame()
df9 = pd.DataFrame()
df10 = pd.DataFrame()
df11 = pd.DataFrame()
df12 = pd.DataFrame()
df13 = pd.DataFrame()
df14 = pd.DataFrame()

# %% [markdown]
# ### Page 3 Loop

# %%
for i in soup2:
    address2 = soup2.find_all (class_= 'list-card-addr')
    price2 = list(soup2.find_all (class_='list-card-price'))
    details2 = list(soup2.find_all("ul", class_="list-card-details"))
            

df2['prices'] = price2
df2['address'] = address2
df2['details'] = details2


urls = []

for link in soup2.find_all("article"):
    href = link.find('a',class_="list-card-link")
    addresses = href.find('address')
    addresses.extract()
    urls.append(href)

# %%
# Import the urls into a column called links
df2['links'] = urls
df2['links'] = df2['links'].astype('str')

# %%
len(df2)
# Out:
# 40

# %% [markdown]
# ### Page 4 Loop

# %%
for i in soup3:
    address3 = soup3.find_all (class_= 'list-card-addr')
    price3 = list(soup3.find_all (class_='list-card-price'))
    details3 = list(soup3.find_all("ul", class_="list-card-details"))
            

df3['prices'] = price3
df3['address'] = address3
df3['details'] = details3


urls = []

for link in soup3.find_all("article"):
    href = link.find('a',class_="list-card-link")
    addresses = href.find('address')
    addresses.extract()
    urls.append(href)

# %%
# Import the urls into a column called links
df3['links'] = urls
df3['links'] = df3['links'].astype('str')

# %%
len(df3)
# Out:
# 40

# %% [markdown]
# ### Page 5 Loop

# %%
for i in soup4:
    address4 = soup4.find_all (class_= 'list-card-addr')
    price4 = list(soup4.find_all (class_='list-card-price'))
    details4 = list(soup4.find_all("ul", class_="list-card-details"))
            

df4['prices'] = price4
df4['address'] = address4
df4['details'] = details4


urls = []

for link in soup4.find_all("article"):
    href = link.find('a',class_="list-card-link")
    addresses = href.find('address')
    addresses.extract()
    urls.append(href)

# %%
# Import the urls into a column called links
df4['links'] = urls
df4['links'] = df4['links'].astype('str')

# %%
len(df4)
# Out:
# 40

# %% [markdown]
# ### Page 6 Loop

# %%
for i in soup5:
    address5 = soup5.find_all (class_= 'list-card-addr')
    price5 = list(soup5.find_all (class_='list-card-price'))
    details5 = list(soup5.find_all("ul", class_="list-card-details"))
            

df5['prices'] = price5
df5['address'] = address5
df5['details'] = details5


urls = []

for link in soup5.find_all("article"):
    href = link.find('a',class_="list-card-link")
    addresses = href.find('address')
    addresses.extract()
    urls.append(href)

# %%
# Import the urls into a column called links
df5['links'] = urls
df5['links'] = df5['links'].astype('str')

# %%
len(df5)
# Out:
# 40

# %% [markdown]
# ### Page 7 Loop

# %%
for i in soup6:
    address6 = soup6.find_all (class_= 'list-card-addr')
    price6 = list(soup6.find_all (class_='list-card-price'))
    details6 = list(soup6.find_all("ul", class_="list-card-details"))
            

df6['prices'] = price6
df6['address'] = address6
df6['details'] = details6


urls = []

for link in soup6.find_all("article"):
    href = link.find('a',class_="list-card-link")
    addresses = href.find('address')
    addresses.extract()
    urls.append(href)

# %%
# Import the urls into a column called links
df6['links'] = urls
df6['links'] = df6['links'].astype('str')

# %%
len(df6)
# Out:
# 40

# %% [markdown]
# ### Page 8 Loop

# %%
for i in soup7:
    address7 = soup7.find_all (class_= 'list-card-addr')
    price7 = list(soup7.find_all (class_='list-card-price'))
    details7 = list(soup7.find_all("ul", class_="list-card-details"))
            

df7['prices'] = price7
df7['address'] = address7
df7['details'] = details7


urls = []

for link in soup7.find_all("article"):
    href = link.find('a',class_="list-card-link")
    addresses = href.find('address')
    addresses.extract()
    urls.append(href)

# %%
# Import the urls into a column called links
df7['links'] = urls
df7['links'] = df7['links'].astype('str')

# %%
len(df7)
# Out:
# 40

# %% [markdown]
# ### Page 9 Loop

# %%
for i in soup8:
    address8 = soup8.find_all (class_= 'list-card-addr')
    price8 = list(soup8.find_all (class_='list-card-price'))
    details8 = list(soup8.find_all("ul", class_="list-card-details"))
            

df8['prices'] = price8
df8['address'] = address8
df8['details'] = details8


urls = []

for link in soup8.find_all("article"):
    href = link.find('a',class_="list-card-link")
    addresses = href.find('address')
    addresses.extract()
    urls.append(href)

# %%
# Import the urls into a column called links
df8['links'] = urls
df8['links'] = df8['links'].astype('str')

# %%
len(df8)
# Out:
# 40

# %% [markdown]
# ### Page 10 Loop

# %%
for i in soup9:
    address9 = soup9.find_all (class_= 'list-card-addr')
    price9 = list(soup9.find_all (class_='list-card-price'))
    details9 = list(soup9.find_all("ul", class_="list-card-details"))
            

df9['prices'] = price9
df9['address'] = address9
df9['details'] = details9


urls = []

for link in soup9.find_all("article"):
    href = link.find('a',class_="list-card-link")
    addresses = href.find('address')
    addresses.extract()
    urls.append(href)

# %%
# Import the urls into a column called links
df9['links'] = urls
df9['links'] = df9['links'].astype('str')

# %%
len(df9)
# Out:
# 40

# %% [markdown]
# ### Page 11 Loop

# %%
for i in soup10:
    address10 = soup10.find_all (class_= 'list-card-addr')
    price10 = list(soup10.find_all (class_='list-card-price'))
    details10 = list(soup10.find_all("ul", class_="list-card-details"))
            

df10['prices'] = price10
df10['address'] = address10
df10['details'] = details10


urls = []

for link in soup10.find_all("article"):
    href = link.find('a',class_="list-card-link")
    addresses = href.find('address')
    addresses.extract()
    urls.append(href)

# %%
# Import the urls into a column called links
df10['links'] = urls
df10['links'] = df10['links'].astype('str')

# %%
len(df10)
# Out:
# 40

# %% [markdown]
# ### Page 12 Loop

# %%
for i in soup11:
    address11 = soup11.find_all (class_= 'list-card-addr')
    price11 = list(soup11.find_all (class_='list-card-price'))
    details11 = list(soup11.find_all("ul", class_="list-card-details"))
            

df11['prices'] = price11
df11['address'] = address11
df11['details'] = details11


urls = []

for link in soup11.find_all("article"):
    href = link.find('a',class_="list-card-link")
    addresses = href.find('address')
    addresses.extract()
    urls.append(href)

# %%
# Import the urls into a column called links
df11['links'] = urls
df11['links'] = df11['links'].astype('str')

# %%
len(df11)
# Out:
# 40

# %% [markdown]
# ### Page 13 Loop

# %%
for i in soup12:
    address12 = soup12.find_all (class_= 'list-card-addr')
    price12 = list(soup12.find_all (class_='list-card-price'))
    details12 = list(soup12.find_all("ul", class_="list-card-details"))
            

df12['prices'] = price12
df12['address'] = address12
df12['details'] = details12


urls = []

for link in soup12.find_all("article"):
    href = link.find('a',class_="list-card-link")
    addresses = href.find('address')
    addresses.extract()
    urls.append(href)

# %%
# Import the urls into a column called links
df12['links'] = urls
df12['links'] = df12['links'].astype('str')

# %%
len(df12)
# Out:
# 40

# %% [markdown]
# ### Page 14 Loop

# %%
for i in soup13:
    address13 = soup13.find_all (class_= 'list-card-addr')
    price13 = list(soup13.find_all (class_='list-card-price'))
    details13 = list(soup13.find_all("ul", class_="list-card-details"))
            

df13['prices'] = price13
df13['address'] = address13
df13['details'] = details13


urls = []

for link in soup13.find_all("article"):
    href = link.find('a',class_="list-card-link")
    addresses = href.find('address')
    addresses.extract()
    urls.append(href)

# %%
# Import the urls into a column called links
df13['links'] = urls
df13['links'] = df13['links'].astype('str')

# %%
len(df13)
# Out:
# 40

# %% [markdown]
# ### Page 15 Loop

# %%
for i in soup14:
    address14 = soup14.find_all (class_= 'list-card-addr')
    price14 = list(soup14.find_all (class_='list-card-price'))
    details14 = list(soup14.find_all("ul", class_="list-card-details"))
            

df14['prices'] = price14
df14['address'] = address14
df14['details'] = details14


urls = []

for link in soup14.find_all("article"):
    href = link.find('a',class_="list-card-link")
    addresses = href.find('address')
    addresses.extract()
    urls.append(href)

# %%
# Import the urls into a column called links
df14['links'] = urls
df14['links'] = df14['links'].astype('str')

# %%
len(df14)
# Out:
# 40

# %% [markdown]
# ### Now that all 10 pages have been looped and scraped, we can now append all dataframes together into one dataframe
# *Note: The first and second dataframes have already been appended from above. So we start by appending df2

# %%
# Now Append all dataframes together
df = df.append(df2, ignore_index = True) 
df = df.append(df3, ignore_index = True) 
df = df.append(df4, ignore_index = True) 
df = df.append(df5, ignore_index = True) 
df = df.append(df6, ignore_index = True) 
df = df.append(df7, ignore_index = True) 
df = df.append(df8, ignore_index = True) 
df = df.append(df9, ignore_index = True)
df = df.append(df10, ignore_index = True)
df = df.append(df11, ignore_index = True)
df = df.append(df12, ignore_index = True)
df = df.append(df13, ignore_index = True)
df = df.append(df14, ignore_index = True)

# %%
# See length of dataframe
len(df)
# Out:
# 600

# %%
# Lets look at first 50 rows
df.head(50)
# Out:
#            prices                                            address  \
# 0    [$1,019,000]            [4810 48th St NW, Washington, DC 20016]
# 1    [$1,049,999]               [1323 F St NE, Washington, DC 20002]
# 2      [$395,000]   [1669 Columbia Rd NW #410, Washington, DC 20009]
# 3    [$1,795,000]     [3750 Northampton St NW, Washington, DC 20015]
# 4    [$1,499,000]  [609 Maryland Ave NE UNIT 5, Washington, DC 20...
# 5    [$1,295,000]            [2349 King Pl NW, Washington, DC 20007]
# 6      [$995,000]            [6125 32nd St NW, Washington, DC 20015]
# 7   [$13,750,000]       [3301 Fessenden St NW, Washington, DC 20008]
# 8      [$875,000]               [1311 D St NE, Washington, DC 20002]
# 9      [$849,000]            [3806 13th St NW, Washington, DC 20011]
# 10     [$585,000]     [1715 15th St NW APT 25, Washington, DC 20009]
# 11     [$135,000]     [4721 1st St SW APT 103, Washington, DC 20032]
# 12     [$449,900]               [3008 K St SE, Washington, DC 20019]
# 13   [$1,595,000]              [337 6th St SE, Washington, DC 20003]
# 14     [$389,000]            [5119 Bass Pl SE, Washington, DC 20019]
# 15     [$459,000]               [3315 B St SE, Washington, DC 20019]
# 16     [$775,000]                [503 D St SE, Washington, DC 20003]
# 17     [$845,000]           [1917 9 1/2 St NW, Washington, DC 20001]
# 18     [$250,000]  [612 Eastern Ave NE APT 203, Washington, DC 20...
# 19     [$749,000]         [2010 Jackson St NE, Washington, DC 20018]
# 20   [$1,599,000]               [4809 V St NW, Washington, DC 20007]
# 21     [$273,733]  [3205 Georgia Ave NW UNIT 307, Washington, DC ...
# 22  [$12,000,000]        [3036 Woodland Dr NW, Washington, DC 20008]
# 23     [$475,000]     [1652 Fort Dupont St SE, Washington, DC 20020]
# 24     [$459,900]           [4650 Hayes St NE, Washington, DC 20019]
# 25     [$825,000]             [1407 Oak St NW, Washington, DC 20010]
# 26     [$865,000]             [513 14th St NE, Washington, DC 20002]
# 27   [$1,595,000]            [3011 Dent Pl NW, Washington, DC 20007]
# 28   [$1,165,000]    [404 Constitution Ave NE, Washington, DC 20002]
# 29     [$699,000]               [1835 E St NE, Washington, DC 20002]
# 30     [$549,900]                [353 O St SW, Washington, DC 20024]
# 31     [$269,999]  [2131 Suitland Ter SE UNIT B, Washington, DC 2...
# 32     [$349,495]     [1929 1st St NW APT 101, Washington, DC 20001]
# 33     [$419,900]            [5105 Just St NE, Washington, DC 20019]
# 34   [$2,390,000]          [3314 Ordway St NW, Washington, DC 20008]
# 35     [$995,000]                [712 C St NE, Washington, DC 20002]
# 36     [$125,000]  [625 Chesapeake St SE #207, Washington, DC 20032]
# 37     [$359,000]  [1311 Delaware Avenue Sw 826/s #S-827, Washing...
# 38     [$569,999]  [108 Tennessee Ave NE APT 3, Washington, DC 20...
# 39     [$479,900]           [1432 Ridge Pl SE, Washington, DC 20020]
# 40  [$15,999,900]         [2507 Foxhall Rd NW, Washington, DC 20007]
# 41   [$1,199,000]             [2019 5th St NW, Washington, DC 20001]
# 42     [$365,000]         [725 Atlantic St SE, Washington, DC 20032]
# 43     [$540,000]        [1906 4th St NE #P-1, Washington, DC 20002]
# 44     [$855,000]  [1000 New Jersey Ave SE PENTHOUSE 9, Washingto...
# 45     [$675,000]       [3812 Hansberry Ct NE, Washington, DC 20018]
# 46     [$899,000]                 [83 P St NW, Washington, DC 20001]
# 47   [$2,290,000]         [5800 Oregon Ave NW, Washington, DC 20015]
# 48   [$1,860,000]           [3069 Canal St NW, Washington, DC 20007]
# 49     [$299,999]  [1660 W Virginia Ave NE APT 201, Washington, D...
#
#                                               details  \
# 0   [[3, [ ,  , bds]], [3, [ ,  , ba]], [2,500, [ ...
# 1   [[3, [ ,  , bds]], [3, [ ,  , ba]], [1,515, [ ...
# 2   [[2, [ ,  , bds]], [2, [ ,  , ba]], [1,120, [ ...
# 3   [[4, [ ,  , bds]], [4, [ ,  , ba]], [3,082, [ ...
# 4   [[2, [ ,  , bds]], [3, [ ,  , ba]], [2,634, [ ...
# 5   [[3, [ ,  , bds]], [3, [ ,  , ba]], [3,350, [ ...
# 6   [[3, [ ,  , bds]], [2, [ ,  , ba]], [1,758, [ ...
# 7   [[11, [ ,  , bds]], [17, [ ,  , ba]], [17,631,...
# 8   [[4, [ ,  , bds]], [2, [ ,  , ba]], [1,748, [ ...
# 9   [[3, [ ,  , bds]], [3, [ ,  , ba]], [2,535, [ ...
# 10  [[2, [ ,  , bds]], [2, [ ,  , ba]], [1,002, [ ...
# 11  [[2, [ ,  , bds]], [1, [ ,  , ba]], [717, [ , ...
# 12  [[3, [ ,  , bds]], [2, [ ,  , ba]], [1,302, [ ...
# 13  [[4, [ ,  , bds]], [3, [ ,  , ba]], [2,391, [ ...
# 14  [[2, [ ,  , bds]], [2, [ ,  , ba]], [1,452, [ ...
# 15  [[4, [ ,  , bds]], [3, [ ,  , ba]], [1,800, [ ...
# 16  [[3, [ ,  , bds]], [1, [ ,  , ba]], [1,494, [ ...
# 17  [[3, [ ,  , bds]], [2, [ ,  , ba]], [1,260, [ ...
# 18  [[3, [ ,  , bds]], [2, [ ,  , ba]], [1,317, [ ...
# 19  [[4, [ ,  , bds]], [4, [ ,  , ba]], [1,526, [ ...
# 20  [[4, [ ,  , bds]], [3, [ ,  , ba]], [2,366, [ ...
# 21  [[2, [ ,  , bds]], [1, [ ,  , ba]], [667, [ , ...
# 22  [[8, [ ,  , bds]], [11, [ ,  , ba]], [10,823, ...
# 23  [[4, [ ,  , bds]], [2, [ ,  , ba]], [1,536, [ ...
# 24  [[3, [ ,  , bds]], [3, [ ,  , ba]], [1,054, [ ...
# 25  [[3, [ ,  , bds]], [4, [ ,  , ba]], [2,160, [ ...
# 26  [[3, [ ,  , bds]], [2, [ ,  , ba]], [1,374, [ ...
# 27  [[3, [ ,  , bds]], [2, [ ,  , ba]], [2,300, [ ...
# 28  [[4, [ ,  , bds]], [3, [ ,  , ba]], [2,369, [ ...
# 29  [[3, [ ,  , bds]], [2, [ ,  , ba]], [1,546, [ ...
# 30  [[3, [ ,  , bds]], [2, [ ,  , ba]], [1,595, [ ...
# 31  [[2, [ ,  , bds]], [1, [ ,  , ba]], [824, [ , ...
# 32  [[1, [ ,  , bd]], [1, [ ,  , ba]], [525, [ ,  ...
# 33  [[3, [ ,  , bds]], [2, [ ,  , ba]], [810, [ , ...
# 34  [[3, [ ,  , bds]], [4, [ ,  , ba]], [3,700, [ ...
# 35  [[3, [ ,  , bds]], [3, [ ,  , ba]], [1,764, [ ...
# 36  [[2, [ ,  , bds]], [1, [ ,  , ba]], [768, [ , ...
# 37  [[2, [ ,  , bds]], [3, [ ,  , ba]], [1,350, [ ...
# 38  [[2, [ ,  , bds]], [1, [ ,  , ba]], [850, [ , ...
# 39  [[3, [ ,  , bds]], [2, [ ,  , ba]], [1,776, [ ...
# 40  [[3, [ ,  , bds]], [3, [ ,  , ba]], [2,500, [ ...
# 41  [[3, [ ,  , bds]], [3, [ ,  , ba]], [1,515, [ ...
# 42  [[2, [ ,  , bds]], [2, [ ,  , ba]], [1,120, [ ...
# 43  [[4, [ ,  , bds]], [4, [ ,  , ba]], [3,082, [ ...
# 44  [[2, [ ,  , bds]], [3, [ ,  , ba]], [2,634, [ ...
# 45  [[3, [ ,  , bds]], [3, [ ,  , ba]], [3,350, [ ...
# 46  [[3, [ ,  , bds]], [2, [ ,  , ba]], [1,758, [ ...
# 47  [[11, [ ,  , bds]], [17, [ ,  , ba]], [17,631,...
# 48  [[4, [ ,  , bds]], [2, [ ,  , ba]], [1,748, [ ...
# 49  [[3, [ ,  , bds]], [3, [ ,  , ba]], [2,535, [ ...
#
#                                                 links
# 0   <a class="list-card-link list-card-link-top-ma...
# 1   <a class="list-card-link list-card-link-top-ma...
# 2   <a class="list-card-link list-card-link-top-ma...
# 3   <a class="list-card-link list-card-link-top-ma...
# 4   <a class="list-card-link list-card-link-top-ma...
# 5   <a class="list-card-link list-card-link-top-ma...
# 6   <a class="list-card-link list-card-link-top-ma...
# 7   <a class="list-card-link list-card-link-top-ma...
# 8   <a class="list-card-link list-card-link-top-ma...
# 9   <a class="list-card-link list-card-link-top-ma...
# 10  <a class="list-card-link list-card-link-top-ma...
# 11  <a class="list-card-link list-card-link-top-ma...
# 12  <a class="list-card-link list-card-link-top-ma...
# 13  <a class="list-card-link list-card-link-top-ma...
# 14  <a class="list-card-link list-card-link-top-ma...
# 15  <a class="list-card-link list-card-link-top-ma...
# 16  <a class="list-card-link list-card-link-top-ma...
# 17  <a class="list-card-link list-card-link-top-ma...
# 18  <a class="list-card-link list-card-link-top-ma...
# 19  <a class="list-card-link list-card-link-top-ma...
# 20  <a class="list-card-link list-card-link-top-ma...
# 21  <a class="list-card-link list-card-link-top-ma...
# 22  <a class="list-card-link list-card-link-top-ma...
# 23  <a class="list-card-link list-card-link-top-ma...
# 24  <a class="list-card-link list-card-link-top-ma...
# 25  <a class="list-card-link list-card-link-top-ma...
# 26  <a class="list-card-link list-card-link-top-ma...
# 27  <a class="list-card-link list-card-link-top-ma...
# 28  <a class="list-card-link list-card-link-top-ma...
# 29  <a class="list-card-link list-card-link-top-ma...
# 30  <a class="list-card-link list-card-link-top-ma...
# 31  <a class="list-card-link list-card-link-top-ma...
# 32  <a class="list-card-link list-card-link-top-ma...
# 33  <a class="list-card-link list-card-link-top-ma...
# 34  <a class="list-card-link list-card-link-top-ma...
# 35  <a class="list-card-link list-card-link-top-ma...
# 36  <a class="list-card-link list-card-link-top-ma...
# 37  <a class="list-card-link list-card-link-top-ma...
# 38  <a class="list-card-link list-card-link-top-ma...
# 39  <a class="list-card-link list-card-link-top-ma...
# 40  <a class="list-card-link list-card-link-top-ma...
# 41  <a class="list-card-link list-card-link-top-ma...
# 42  <a class="list-card-link list-card-link-top-ma...
# 43  <a class="list-card-link list-card-link-top-ma...
# 44  <a class="list-card-link list-card-link-top-ma...
# 45  <a class="list-card-link list-card-link-top-ma...
# 46  <a class="list-card-link list-card-link-top-ma...
# 47  <a class="list-card-link list-card-link-top-ma...
# 48  <a class="list-card-link list-card-link-top-ma...
# 49  <a class="list-card-link list-card-link-top-ma...

# %% [markdown]
# # Data Cleaning
# ### Now that we have the scraped Zillow data, we need to clean this data up a bit for better analysis later on and easier handling in the BI Dashboard

# %%
# Rearange columns a bit
df = df[['prices', 'address', 'links', 'details']]

# %%
# Convert columns to string
df['prices'] = df['prices'].astype('str')
df['address'] = df['address'].astype('str')
df['details'] = df['details'].astype('str')

# %%
# Show top 5 rows
df.head()
# Out:
#                                               prices  \
# 0  <div aria-label="$1,019,000" class="list-card-...
# 1  <div aria-label="$1,049,999" class="list-card-...
# 2  <div aria-label="$395,000" class="list-card-pr...
# 3  <div aria-label="$1,795,000" class="list-card-...
# 4  <div aria-label="$1,499,000" class="list-card-...
#
#                                              address  \
# 0  <address class="list-card-addr">4810 48th St N...
# 1  <address class="list-card-addr">1323 F St NE, ...
# 2  <address class="list-card-addr">1669 Columbia ...
# 3  <address class="list-card-addr">3750 Northampt...
# 4  <address class="list-card-addr">609 Maryland A...
#
#                                                links  \
# 0  <a class="list-card-link list-card-link-top-ma...
# 1  <a class="list-card-link list-card-link-top-ma...
# 2  <a class="list-card-link list-card-link-top-ma...
# 3  <a class="list-card-link list-card-link-top-ma...
# 4  <a class="list-card-link list-card-link-top-ma...
#
#                                              details
# 0  <ul class="list-card-details"><li class="">3<a...
# 1  <ul class="list-card-details"><li class="">3<a...
# 2  <ul class="list-card-details"><li class="">2<a...
# 3  <ul class="list-card-details"><li class="">4<a...
# 4  <ul class="list-card-details"><li class="">2<a...

# %% [markdown]
# ### Clean Prices Column
# - HTML needs to be removed
# - Listing prices are collected twice and needs to only show once

# %%
# Keep only last 20 characters to remove some unwanted string characters and 2nd price reocurrence
df['prices'] = df['prices'].str[-20:]
df.head()
# Out:
#                  prices                                            address  \
# 0  ce">$1,019,000</div>  <address class="list-card-addr">4810 48th St N...
# 1  ce">$1,049,999</div>  <address class="list-card-addr">1323 F St NE, ...
# 2  rice">$395,000</div>  <address class="list-card-addr">1669 Columbia ...
# 3  ce">$1,795,000</div>  <address class="list-card-addr">3750 Northampt...
# 4  ce">$1,499,000</div>  <address class="list-card-addr">609 Maryland A...
#
#                                                links  \
# 0  <a class="list-card-link list-card-link-top-ma...
# 1  <a class="list-card-link list-card-link-top-ma...
# 2  <a class="list-card-link list-card-link-top-ma...
# 3  <a class="list-card-link list-card-link-top-ma...
# 4  <a class="list-card-link list-card-link-top-ma...
#
#                                              details
# 0  <ul class="list-card-details"><li class="">3<a...
# 1  <ul class="list-card-details"><li class="">3<a...
# 2  <ul class="list-card-details"><li class="">2<a...
# 3  <ul class="list-card-details"><li class="">4<a...
# 4  <ul class="list-card-details"><li class="">2<a...

# %%
# Extract and keep 1 listing price as dollar amount 
df['prices'] = df['prices'].str.extract('(\$[0-9,.]+)')
df.head()
# Out:
#        prices                                            address  \
# 0  $1,019,000  <address class="list-card-addr">4810 48th St N...
# 1  $1,049,999  <address class="list-card-addr">1323 F St NE, ...
# 2    $395,000  <address class="list-card-addr">1669 Columbia ...
# 3  $1,795,000  <address class="list-card-addr">3750 Northampt...
# 4  $1,499,000  <address class="list-card-addr">609 Maryland A...
#
#                                                links  \
# 0  <a class="list-card-link list-card-link-top-ma...
# 1  <a class="list-card-link list-card-link-top-ma...
# 2  <a class="list-card-link list-card-link-top-ma...
# 3  <a class="list-card-link list-card-link-top-ma...
# 4  <a class="list-card-link list-card-link-top-ma...
#
#                                              details
# 0  <ul class="list-card-details"><li class="">3<a...
# 1  <ul class="list-card-details"><li class="">3<a...
# 2  <ul class="list-card-details"><li class="">2<a...
# 3  <ul class="list-card-details"><li class="">4<a...
# 4  <ul class="list-card-details"><li class="">2<a...

# %% [markdown]
# ### Clean Address Column
# - HTML needs to be removed

# %%
# Remove all html tags from address
df['address'] = df['address'].replace('<address class="list-card-addr">', ' ', regex=True)
df['address'] = df['address'].replace('</address>', ' ', regex=True)
df.head()
# Out:
#        prices                                            address  \
# 0  $1,019,000             4810 48th St NW, Washington, DC 20016
# 1  $1,049,999                1323 F St NE, Washington, DC 20002
# 2    $395,000    1669 Columbia Rd NW #410, Washington, DC 20009
# 3  $1,795,000      3750 Northampton St NW, Washington, DC 20015
# 4  $1,499,000   609 Maryland Ave NE UNIT 5, Washington, DC 20...
#
#                                                links  \
# 0  <a class="list-card-link list-card-link-top-ma...
# 1  <a class="list-card-link list-card-link-top-ma...
# 2  <a class="list-card-link list-card-link-top-ma...
# 3  <a class="list-card-link list-card-link-top-ma...
# 4  <a class="list-card-link list-card-link-top-ma...
#
#                                              details
# 0  <ul class="list-card-details"><li class="">3<a...
# 1  <ul class="list-card-details"><li class="">3<a...
# 2  <ul class="list-card-details"><li class="">2<a...
# 3  <ul class="list-card-details"><li class="">4<a...
# 4  <ul class="list-card-details"><li class="">2<a...

# %% [markdown]
# ### Clean Links Column
# - HTML needs to be removed

# %%
# Remove all html tags from links
df['links'] = df['links'].replace('<a class="list-card-link list-card-link-top-margin" href="', ' ', regex=True)
df['links'] = df['links'].replace('" tabindex="0"></a>', ' ', regex=True)
df.head()
# Out:
#        prices                                            address  \
# 0  $1,019,000             4810 48th St NW, Washington, DC 20016
# 1  $1,049,999                1323 F St NE, Washington, DC 20002
# 2    $395,000    1669 Columbia Rd NW #410, Washington, DC 20009
# 3  $1,795,000      3750 Northampton St NW, Washington, DC 20015
# 4  $1,499,000   609 Maryland Ave NE UNIT 5, Washington, DC 20...
#
#                                                links  \
# 0   https://www.zillow.com/homedetails/4810-48th-...
# 1   https://www.zillow.com/homedetails/1323-F-St-...
# 2   https://www.zillow.com/homedetails/1669-Colum...
# 3   https://www.zillow.com/homedetails/3750-North...
# 4   https://www.zillow.com/homedetails/609-Maryla...
#
#                                              details
# 0  <ul class="list-card-details"><li class="">3<a...
# 1  <ul class="list-card-details"><li class="">3<a...
# 2  <ul class="list-card-details"><li class="">2<a...
# 3  <ul class="list-card-details"><li class="">4<a...
# 4  <ul class="list-card-details"><li class="">2<a...

# %% [markdown]
# ### Clean Details Column
# - HTML needs to be removed
# - Beds, Baths, and SQFT need to be seperated

# %%
# Remove all characters from each value of details except numbers and commas
def find_number(text):
    num = re.findall(r'[0-9,]+',text)
    return " ".join(num)
df['details']=df['details'].apply(lambda x: find_number(x))

# %%
# Trim any leading and trailing white spaces from the details column to avoid errors when splitting
df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
df.head()
# Out:
#        prices                                           address  \
# 0  $1,019,000             4810 48th St NW, Washington, DC 20016
# 1  $1,049,999                1323 F St NE, Washington, DC 20002
# 2    $395,000    1669 Columbia Rd NW #410, Washington, DC 20009
# 3  $1,795,000      3750 Northampton St NW, Washington, DC 20015
# 4  $1,499,000  609 Maryland Ave NE UNIT 5, Washington, DC 20002
#
#                                                links    details
# 0  https://www.zillow.com/homedetails/4810-48th-S...  3 3 2,500
# 1  https://www.zillow.com/homedetails/1323-F-St-N...  3 3 1,515
# 2  https://www.zillow.com/homedetails/1669-Columb...  2 2 1,120
# 3  https://www.zillow.com/homedetails/3750-Northa...  4 4 3,082
# 4  https://www.zillow.com/homedetails/609-Marylan...  2 3 2,634

# %%
# Split details column into 3 new columns beds, baths, sqft
df['beds'] = df.details.str.split(' ', expand = True)[0]
df['baths'] = df.details.str.split(' ', expand = True)[1]
df['sqft'] = df.details.str.split(' ', expand = True)[2]

# %%
# Show top 5 rows
df.head()
# Out:
#        prices                                           address  \
# 0  $1,019,000             4810 48th St NW, Washington, DC 20016
# 1  $1,049,999                1323 F St NE, Washington, DC 20002
# 2    $395,000    1669 Columbia Rd NW #410, Washington, DC 20009
# 3  $1,795,000      3750 Northampton St NW, Washington, DC 20015
# 4  $1,499,000  609 Maryland Ave NE UNIT 5, Washington, DC 20002
#
#                                                links    details beds baths  \
# 0  https://www.zillow.com/homedetails/4810-48th-S...  3 3 2,500    3     3
# 1  https://www.zillow.com/homedetails/1323-F-St-N...  3 3 1,515    3     3
# 2  https://www.zillow.com/homedetails/1669-Columb...  2 2 1,120    2     2
# 3  https://www.zillow.com/homedetails/3750-Northa...  4 4 3,082    4     4
# 4  https://www.zillow.com/homedetails/609-Marylan...  2 3 2,634    2     3
#
#     sqft
# 0  2,500
# 1  1,515
# 2  1,120
# 3  3,082
# 4  2,634

# %%
# Remove commas from sqft and convert to float
df["sqft"] = df["sqft"].str.replace(",","").astype(float)

# %%
# Remove $ from prices column and remove commas
df['prices'] = df['prices'].str.replace('$', '')
df['prices'] = df['prices'].str.replace(',', '')

# %%
#convert prices column to float
df['prices'] = df['prices'].astype('float')

# %%
df.head()
# Out:
#       prices                                           address  \
# 0  1019000.0             4810 48th St NW, Washington, DC 20016
# 1  1049999.0                1323 F St NE, Washington, DC 20002
# 2   395000.0    1669 Columbia Rd NW #410, Washington, DC 20009
# 3  1795000.0      3750 Northampton St NW, Washington, DC 20015
# 4  1499000.0  609 Maryland Ave NE UNIT 5, Washington, DC 20002
#
#                                                links    details beds baths  \
# 0  https://www.zillow.com/homedetails/4810-48th-S...  3 3 2,500    3     3
# 1  https://www.zillow.com/homedetails/1323-F-St-N...  3 3 1,515    3     3
# 2  https://www.zillow.com/homedetails/1669-Columb...  2 2 1,120    2     2
# 3  https://www.zillow.com/homedetails/3750-Northa...  4 4 3,082    4     4
# 4  https://www.zillow.com/homedetails/609-Marylan...  2 3 2,634    2     3
#
#      sqft
# 0  2500.0
# 1  1515.0
# 2  1120.0
# 3  3082.0
# 4  2634.0

# %% [markdown]
# ## Extract City and State from Address Column

# %%
# Split address column into street, city, and statezip
df[['street','city','statezip']] = df.address.str.split(',',expand=True)

# %%
# Show top 2 rows
df.head(2)
# Out:
#       prices                                address  \
# 0  1019000.0  4810 48th St NW, Washington, DC 20016
# 1  1049999.0     1323 F St NE, Washington, DC 20002
#
#                                                links    details beds baths  \
# 0  https://www.zillow.com/homedetails/4810-48th-S...  3 3 2,500    3     3
# 1  https://www.zillow.com/homedetails/1323-F-St-N...  3 3 1,515    3     3
#
#      sqft           street         city   statezip
# 0  2500.0  4810 48th St NW   Washington   DC 20016
# 1  1515.0     1323 F St NE   Washington   DC 20002

# %%
# Trim any leading and trailing spaces from statezip column to avoid errors while splitting zip column
df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# %%
# Split statezip column into  new columns state and zip
df['state'] = df.statezip.str.split(' ', expand = True)[0]
df['zip'] = df.statezip.str.split(' ', expand = True)[1]

# %%
# Show top 2 rows
df.head(2)
# Out:
#       prices                                address  \
# 0  1019000.0  4810 48th St NW, Washington, DC 20016
# 1  1049999.0     1323 F St NE, Washington, DC 20002
#
#                                                links    details beds baths  \
# 0  https://www.zillow.com/homedetails/4810-48th-S...  3 3 2,500    3     3
# 1  https://www.zillow.com/homedetails/1323-F-St-N...  3 3 1,515    3     3
#
#      sqft           street        city  statezip state    zip
# 0  2500.0  4810 48th St NW  Washington  DC 20016    DC  20016
# 1  1515.0     1323 F St NE  Washington  DC 20002    DC  20002

# %%
# Now drop unwanted columns details and statezip
df = df.drop('details', 1)
df = df.drop('statezip', 1)
df.head()
# Out:
#       prices                                           address  \
# 0  1019000.0             4810 48th St NW, Washington, DC 20016
# 1  1049999.0                1323 F St NE, Washington, DC 20002
# 2   395000.0    1669 Columbia Rd NW #410, Washington, DC 20009
# 3  1795000.0      3750 Northampton St NW, Washington, DC 20015
# 4  1499000.0  609 Maryland Ave NE UNIT 5, Washington, DC 20002
#
#                                                links beds baths    sqft  \
# 0  https://www.zillow.com/homedetails/4810-48th-S...    3     3  2500.0
# 1  https://www.zillow.com/homedetails/1323-F-St-N...    3     3  1515.0
# 2  https://www.zillow.com/homedetails/1669-Columb...    2     2  1120.0
# 3  https://www.zillow.com/homedetails/3750-Northa...    4     4  3082.0
# 4  https://www.zillow.com/homedetails/609-Marylan...    2     3  2634.0
#
#                        street        city state    zip
# 0             4810 48th St NW  Washington    DC  20016
# 1                1323 F St NE  Washington    DC  20002
# 2    1669 Columbia Rd NW #410  Washington    DC  20009
# 3      3750 Northampton St NW  Washington    DC  20015
# 4  609 Maryland Ave NE UNIT 5  Washington    DC  20002

# %% [markdown]
# ### Run to look at full dataframe

# %%
df
# Out:
#          prices                                            address  \
# 0     1019000.0              4810 48th St NW, Washington, DC 20016
# 1     1049999.0                 1323 F St NE, Washington, DC 20002
# 2      395000.0     1669 Columbia Rd NW #410, Washington, DC 20009
# 3     1795000.0       3750 Northampton St NW, Washington, DC 20015
# 4     1499000.0   609 Maryland Ave NE UNIT 5, Washington, DC 20002
# 5     1295000.0              2349 King Pl NW, Washington, DC 20007
# 6      995000.0              6125 32nd St NW, Washington, DC 20015
# 7    13750000.0         3301 Fessenden St NW, Washington, DC 20008
# 8      875000.0                 1311 D St NE, Washington, DC 20002
# 9      849000.0              3806 13th St NW, Washington, DC 20011
# 10     585000.0       1715 15th St NW APT 25, Washington, DC 20009
# 11     135000.0       4721 1st St SW APT 103, Washington, DC 20032
# 12     449900.0                 3008 K St SE, Washington, DC 20019
# 13    1595000.0                337 6th St SE, Washington, DC 20003
# 14     389000.0              5119 Bass Pl SE, Washington, DC 20019
# 15     459000.0                 3315 B St SE, Washington, DC 20019
# 16     775000.0                  503 D St SE, Washington, DC 20003
# 17     845000.0             1917 9 1/2 St NW, Washington, DC 20001
# 18     250000.0   612 Eastern Ave NE APT 203, Washington, DC 20019
# 19     749000.0           2010 Jackson St NE, Washington, DC 20018
# 20    1599000.0                 4809 V St NW, Washington, DC 20007
# 21     273733.0  3205 Georgia Ave NW UNIT 307, Washington, DC 2...
# 22   12000000.0          3036 Woodland Dr NW, Washington, DC 20008
# 23     475000.0       1652 Fort Dupont St SE, Washington, DC 20020
# 24     459900.0             4650 Hayes St NE, Washington, DC 20019
# 25     825000.0               1407 Oak St NW, Washington, DC 20010
# 26     865000.0               513 14th St NE, Washington, DC 20002
# 27    1595000.0              3011 Dent Pl NW, Washington, DC 20007
# 28    1165000.0      404 Constitution Ave NE, Washington, DC 20002
# 29     699000.0                 1835 E St NE, Washington, DC 20002
# 30     549900.0                  353 O St SW, Washington, DC 20024
# 31     269999.0  2131 Suitland Ter SE UNIT B, Washington, DC 20020
# 32     349495.0       1929 1st St NW APT 101, Washington, DC 20001
# 33     419900.0              5105 Just St NE, Washington, DC 20019
# 34    2390000.0            3314 Ordway St NW, Washington, DC 20008
# 35     995000.0                  712 C St NE, Washington, DC 20002
# 36     125000.0    625 Chesapeake St SE #207, Washington, DC 20032
# 37     359000.0  1311 Delaware Avenue Sw 826/s #S-827, Washingt...
# 38     569999.0   108 Tennessee Ave NE APT 3, Washington, DC 20002
# 39     479900.0             1432 Ridge Pl SE, Washington, DC 20020
# 40   15999900.0           2507 Foxhall Rd NW, Washington, DC 20007
# 41    1199000.0               2019 5th St NW, Washington, DC 20001
# 42     365000.0           725 Atlantic St SE, Washington, DC 20032
# 43     540000.0          1906 4th St NE #P-1, Washington, DC 20002
# 44     855000.0  1000 New Jersey Ave SE PENTHOUSE 9, Washington...
# 45     675000.0         3812 Hansberry Ct NE, Washington, DC 20018
# 46     899000.0                   83 P St NW, Washington, DC 20001
# 47    2290000.0           5800 Oregon Ave NW, Washington, DC 20015
# 48    1860000.0             3069 Canal St NW, Washington, DC 20007
# 49     299999.0  1660 W Virginia Ave NE APT 201, Washington, DC...
# 50     649900.0           1011 18th St NE #7, Washington, DC 20002
# 51     549950.0            4331 Dubois Pl SE, Washington, DC 20019
# 52     699000.0    3401 Massachusetts Ave SE, Washington, DC 20019
# 53    1699900.0            1601 5th St NW #A, Washington, DC 20001
# 54     589000.0          610 Nicholson St NE, Washington, DC 20011
# 55    1695000.0           4019 Mansion Dr NW, Washington, DC 20007
# 56    4250000.0                 3129 N St NW, Washington, DC 20007
# 57     528499.0     1808 Belmont Rd NW APT 1, Washington, DC 20009
# 58     949900.0                314 5th St NE, Washington, DC 20002
# 59    6830000.0            4615 Dexter St NW, Washington, DC 20007
# 60     200000.0            2330 Payne Ter SE, Washington, DC 20020
# 61    1300000.0          5032 1/2 Dana Pl NW, Washington, DC 20016
# 62     479800.0               3906 1st St SE, Washington, DC 20032
# 63    9495000.0          4400 Garfield St NW, Washington, DC 20007
# 64    1100000.0      2503 Chain Bridge Rd NW, Washington, DC 20016
# 65    1195000.0                 3537 T St NW, Washington, DC 20007
# 66     799000.0            442 M St NW APT 7, Washington, DC 20001
# 67     489900.0     3117 Georgia Ave NW #101, Washington, DC 20010
# 68     714550.0            3129 Newton St NE, Washington, DC 20018
# 69     335000.0  4000 Cathedral Ave NW #706B, Washington, DC 20016
# 70    1649500.0            4849 Rodman St NW, Washington, DC 20016
# 71     450000.0            368 Burbank St SE, Washington, DC 20019
# 72     948800.0                213 6th St NE, Washington, DC 20002
# 73     550000.0      343 Cedar St NW APT 103, Washington, DC 20012
# 74    2990000.0        5115 Rockwood Pkwy NW, Washington, DC 20016
# 75     185250.0  1330 Massachusetts Ave NW APT 407, Washington,...
# 76     565000.0               834 48th St NE, Washington, DC 20019
# 77     895000.0                  306 L St SE, Washington, DC 20003
# 78     885000.0                 1508 E St SE, Washington, DC 20003
# 79        653.0               4517 7th St NW, Washington, DC 20011
# 80     438000.0  3900 Cathedral Ave NW APT 211A, Washington, DC...
# 81   18000000.0  3150 S St NW #PH2C &amp; 1M, Washington, DC 20007
# 82     609900.0        755 Fairmont St NW #2, Washington, DC 20001
# 83     469900.0        777 7th St NW APT 636, Washington, DC 20001
# 84     119900.0       4729 1st St SW APT 203, Washington, DC 20032
# 85    5900000.0    2230 Massachusetts Ave NW, Washington, DC 20008
# 86    1275000.0            2458 Tunlaw Rd NW, Washington, DC 20007
# 87   12950000.0          3120 Woodland Dr NW, Washington, DC 20008
# 88     675000.0           3018 R St NW APT 3, Washington, DC 20007
# 89   12950000.0      3131 Chain Bridge Rd NW, Washington, DC 20016
# 90   10800000.0              3005 45th St NW, Washington, DC 20016
# 91   10995000.0          2860 Woodland Dr NW, Washington, DC 20008
# 92     599999.0                 1648 U St SE, Washington, DC 20020
# 93     349900.0  2600 Sherman Ave NW APT 202, Washington, DC 20001
# 94     375000.0               918 47th St NE, Washington, DC 20019
# 95     420000.0          1211 G St SE UNIT 8, Washington, DC 20003
# 96     520000.0               5133 7th St NW, Washington, DC 20011
# 97    1595000.0              1624 34th St NW, Washington, DC 20007
# 98     739000.0      3039 16th St NW APT 302, Washington, DC 20009
# 99     205000.0                 4611 A St SE, Washington, DC 20019
# 100   5550000.0          2446 Kalorama Rd NW, Washington, DC 20008
# 101    239000.0          950 25th St NW #905, Washington, DC 20037
# 102   1395000.0                 2924 N St NW, Washington, DC 20007
# 103   3197000.0              2005 48th St NW, Washington, DC 20007
# 104    949900.0              2310 39th St NW, Washington, DC 20007
# 105    799900.0               811 E St SE #A, Washington, DC 20003
# 106    375000.0       839 Kennedy St NW #205, Washington, DC 20011
# 107   1149750.0                  412 M St NW, Washington, DC 20001
# 108    289000.0    2651 Birney Pl SE #SE-302, Washington, DC 20020
# 109    575000.0  4025 Connecticut Ave NW APT 205, Washington, D...
# 110    365000.0             5001 Ayers Pl SE, Washington, DC 20019
# 111      1499.0            1420 N St NW #516, Washington, DC 20005
# 112    355000.0      3401 38th St NW APT 224, Washington, DC 20016
# 113    524500.0              3909 Ames St NE, Washington, DC 20019
# 114    849900.0              2624 11th St NW, Washington, DC 20001
# 115    330000.0  2707 Adams Mill Rd NW APT 408, Washington, DC ...
# 116  12000000.0         2900 K St NW APT 601, Washington, DC 20007
# 117   1850000.0                 3300 Q St NW, Washington, DC 20007
# 118    895000.0   1018 E Capitol St NE APT 7, Washington, DC 20003
# 119    675000.0        1023 16th St NE APT 3, Washington, DC 20002
# 120    621500.0            223 Douglas St NE, Washington, DC 20002
# 121   2550000.0              2607 31st St NW, Washington, DC 20008
# 122    649900.0      1211 13th St NW APT 103, Washington, DC 20005
# 123    199900.0        336 Adams St NE APT D, Washington, DC 20002
# 124    520000.0      1514 17th St NW APT 602, Washington, DC 20036
# 125   1540000.0        1641 13th St NW APT B, Washington, DC 20009
# 126    739000.0      2020 12th St NW APT 213, Washington, DC 20009
# 127   1595000.0         3027 Cambridge Pl NW, Washington, DC 20007
# 128    310000.0     2601 Douglass Rd SE #403, Washington, DC 20020
# 129    724950.0    1842 Mintwood Pl NW APT 1, Washington, DC 20009
# 130    799900.0               618 L St NE #1, Washington, DC 20002
# 131    548000.0               3960 2nd St SW, Washington, DC 20032
# 132    624900.0     3225 Grace St NW APT 106, Washington, DC 20007
# 133    600000.0    1040 Bladensburg Rd NE #5, Washington, DC 20002
# 134     95009.0        3701 13th St NW APT 1, Washington, DC 20010
# 135    352500.0           1719 28th Pl SE #B, Washington, DC 20020
# 136    224900.0    215 Emerson St NW APT 201, Washington, DC 20011
# 137    599000.0         1212 M St NW APT 402, Washington, DC 20005
# 138    450000.0         915 E St NW APT 1103, Washington, DC 20004
# 139    550000.0     525 Kennedy St NW UNIT 5, Washington, DC 20011
# 140   1795000.0                 2800 P St NW, Washington, DC 20007
# 141    775000.0     2370 Champlain St NW #31, Washington, DC 20009
# 142    629900.0   1801 Wyoming Ave NW APT 43, Washington, DC 20009
# 143   1795000.0                524 8th St NE, Washington, DC 20002
# 144    167000.0         5014 H St SE APT 101, Washington, DC 20019
# 145    510000.0        1120 Penn St NE APT 1, Washington, DC 20002
# 146    550000.0          4328 Alabama Ave SE, Washington, DC 20019
# 147    769000.0          1314-1314 5th St NW, Washington, DC 20001
# 148    480000.0            1105 Wahler Pl SE, Washington, DC 20032
# 149    625000.0              5032 13th St NE, Washington, DC 20017
# 150   1595000.0           3015 Orchard Ln NW, Washington, DC 20007
# 151    399500.0    3315 Wisconsin Ave NW #B3, Washington, DC 20016
# 152   1649999.0             514 Seward Sq SE, Washington, DC 20003
# 153   6300000.0           2100 Dunmore Ln NW, Washington, DC 20007
# 154    299900.0           1016 17th Pl NE #1, Washington, DC 20002
# 155   1979000.0              4224 16th St NW, Washington, DC 20011
# 156    449900.0      2008 16th St NW APT 102, Washington, DC 20009
# 157    200000.0   208 Farragut St NW APT 104, Washington, DC 20011
# 158    669000.0               5810 8th St NW, Washington, DC 20011
# 159    553700.0                 5117 F St SE, Washington, DC 20019
# 160   1895000.0              5198 27th St NW, Washington, DC 20008
# 161    499900.0           819 D St NE UNIT 3, Washington, DC 20002
# 162    215000.0       3000 7th St NE APT 104, Washington, DC 20017
# 163   2350000.0              2731 31st Pl NW, Washington, DC 20008
# 164   1450000.0   2298 Champlain St NW APT C, Washington, DC 20009
# 165    699000.0                 3224 O St SE, Washington, DC 20020
# 166    224000.0       3366 Brothers Pl SE #2, Washington, DC 20032
# 167   1600000.0        2202 Cathedral Ave NW, Washington, DC 20008
# 168   1650000.0                   24 S St NW, Washington, DC 20001
# 169    165000.0  717 Brandywine St SE APT 301, Washington, DC 2...
# 170    499999.0  1239 Vermont Ave NW APT 605, Washington, DC 20005
# 171    654900.0            3540 Texas Ave SE, Washington, DC 20020
# 172  14999900.0           2509 Foxhall Rd NW, Washington, DC 20007
# 173    699900.0  2111 Wisconsin Ave NW APT 111, Washington, DC ...
# 174    375000.0  5551 Illinois Ave NW APT 202, Washington, DC 2...
# 175    649900.0       2247 12th St NW UNIT 1, Washington, DC 20009
# 176    375000.0  1930 New Hampshire Ave NW APT 18, Washington, ...
# 177    475000.0                 3922 Q St SE, Washington, DC 20020
# 178  12800000.0              1224 30th St NW, Washington, DC 20007
# 179    750000.0          431 Kenyon St NW #1, Washington, DC 20010
# 180    399500.0      1901 19th St NW APT 203, Washington, DC 20009
# 181   1995000.0          611 Maryland Ave NE, Washington, DC 20002
# 182    424000.0           95 Hawthorne Ct NE, Washington, DC 20017
# 183   2100000.0              1509 33rd St NW, Washington, DC 20007
# 184    799900.0             407 Upshur St NW, Washington, DC 20011
# 185    335000.0         2401 H St NW APT 215, Washington, DC 20037
# 186    400000.0     6425 14th St NW UNIT 305, Washington, DC 20012
# 187    234900.0      1800 28th Pl SE APT 201, Washington, DC 20020
# 188    749900.0           911 Potomac Ave SE, Washington, DC 20003
# 189     25000.0      7723 Alaska Ave NW #P-4, Washington, DC 20012
# 190    925000.0      6223 Piney Branch Rd NW, Washington, DC 20011
# 191    599000.0      1358 Girard St NW APT 2, Washington, DC 20009
# 192    499000.0          609 Newton Pl NW #A, Washington, DC 20010
# 193    410000.0      1701 16th St NW APT 350, Washington, DC 20009
# 194    256183.0           410 Eastern Ave NE, Washington, DC 20019
# 195    299000.0  1311 Delaware Ave SW APT S737, Washington, DC ...
# 196    459900.0      2100 19th St NW APT 805, Washington, DC 20009
# 197    160000.0  1440-1446 Tuckerman St NW #A6, Washington, DC ...
# 198    369000.0   76 New York Ave NW APT 302, Washington, DC 20001
# 199    426900.0           1637 A St NE APT 1, Washington, DC 20002
# 200    429900.0           1011 18th St NE #3, Washington, DC 20002
# 201     72760.0         3709 13th St NW #205, Washington, DC 20010
# 202    815000.0  3 Washington Cir NW APT 705, Washington, DC 20037
# 203    699000.0      3261 Sutton Pl NW APT A, Washington, DC 20016
# 204    715000.0      2750 14th St NW APT 609, Washington, DC 20009
# 205    405000.0        1642 Fort Davis Pl SE, Washington, DC 20020
# 206    450000.0    1101 Florida Ave NE APT 1, Washington, DC 20002
# 207   1100000.0       1314 1/2 Wallach Pl NW, Washington, DC 20009
# 208   1150000.0  2351 Champlain St NW APT P3, Washington, DC 20009
# 209    900000.0                 1123 K St NE, Washington, DC 20002
# 210   2400000.0               238 11th St NE, Washington, DC 20002
# 211   1775000.0              1732 18th St NW, Washington, DC 20009
# 212    515000.0           4808 Sargent Rd NE, Washington, DC 20017
# 213    329000.0        1731 20th St NW APT 2, Washington, DC 20009
# 214    549000.0         809 6th St NW APT 24, Washington, DC 20001
# 215    425000.0       1404 Meridian Pl NW #1, Washington, DC 20010
# 216    850000.0  1820 Independence Ave SE APT 4, Washington, DC...
# 217   1549000.0           2707 Woodley Pl NW, Washington, DC 20008
# 218   6450000.0              1691 34th St NW, Washington, DC 20007
# 219    359000.0  3901 Connecticut Ave NW APT 211, Washington, D...
# 220    419400.0     3417 Holmead Pl NW APT 1, Washington, DC 20010
# 221    309000.0         1200 23rd St NW #803, Washington, DC 20037
# 222    610000.0        1120 Penn St NE APT 3, Washington, DC 20002
# 223   1599900.0      1817 13th St NW FLOOR 1, Washington, DC 20009
# 224   1199000.0         3030 K St NW APT 210, Washington, DC 20007
# 225   3999900.0              1717 15th St NW, Washington, DC 20009
# 226   3425000.0          4920 Palisade Ln NW, Washington, DC 20016
# 227    649900.0         816 Oglethorpe St NE, Washington, DC 20011
# 228    415000.0   1308 Clifton St NW APT 117, Washington, DC 20009
# 229    245000.0       6445 Luzon Ave NW #512, Washington, DC 20012
# 230    189999.0  3709 Alabama Ave SE APT 301, Washington, DC 20020
# 231    599900.0        1111 Orren St NE #300, Washington, DC 20002
# 232    275000.0    1415 Girard St NW APT 306, Washington, DC 20009
# 233   1699000.0          5314 1/2 29th St NW, Washington, DC 20015
# 234     99900.0      5000 Call Pl SE APT 203, Washington, DC 20019
# 235    579900.0   1613 Harvard St NW APT 315, Washington, DC 20009
# 236    449000.0              5118 Just St NE, Washington, DC 20019
# 237    900000.0       1401 W Virginia Ave NE, Washington, DC 20002
# 238    649900.0  2818 Connecticut Ave NW APT 201, Washington, D...
# 239    499000.0       1229 12th St NW APT B1, Washington, DC 20005
# 240    699999.0       1213 Holbrook St NE #1, Washington, DC 20002
# 241   5595000.0          2302 Kalorama Rd NW, Washington, DC 20008
# 242    262900.0              2031 38th St SE, Washington, DC 20020
# 243   2290000.0         2817 Dumbarton St NW, Washington, DC 20007
# 244    674000.0        2466 Ontario Rd NW #1, Washington, DC 20009
# 245    375500.0         1229 18th St NE #102, Washington, DC 20002
# 246    449000.0             139 Joliet St SW, Washington, DC 20032
# 247   1225000.0             1309 E St SE #42, Washington, DC 20003
# 248    269000.0       2639 15th St NW APT B2, Washington, DC 20009
# 249    375000.0    2710 Macomb St NW APT 205, Washington, DC 20008
# 250    504900.0            4844 Texas Ave SE, Washington, DC 20019
# 251    485000.0  3205 Georgia Ave NW UNIT 503, Washington, DC 2...
# 252    389000.0              4407 Eads St NE, Washington, DC 20019
# 253    274000.0          1 Scott Cir NW #617, Washington, DC 20036
# 254    298000.0  4491 Macarthur Blvd NW APT 202, Washington, DC...
# 255    352500.0           1717 28th Pl SE #B, Washington, DC 20020
# 256    299999.0        5611 5th St NW APT L4, Washington, DC 20011
# 257    382500.0  4201 Cathedral Ave NW APT 902W, Washington, DC...
# 258    365000.0         822 Kennedy St NW #2, Washington, DC 20011
# 259    159900.0         4130 4th St SE APT 4, Washington, DC 20032
# 260    389000.0    3800 Porter St NW APT 302, Washington, DC 20016
# 261    985000.0          3000 Channing St NE, Washington, DC 20018
# 262    825000.0          904 Butternut St NW, Washington, DC 20012
# 263    549000.0           2000 D St NE APT 6, Washington, DC 20002
# 264    400000.0      1747 Church St NW APT 4, Washington, DC 20036
# 265    765000.0              2403 17th St NE, Washington, DC 20018
# 266    623500.0          1615 Q St NW APT T6, Washington, DC 20009
# 267    199900.0          730 24th St NW #620, Washington, DC 20037
# 268    900000.0                620 7th St NE, Washington, DC 20002
# 269   1195000.0                 1509 R St NW, Washington, DC 20009
# 270   1575000.0             1240 Wylie St NE, Washington, DC 20002
# 271    529900.0         1727 R St NW APT 103, Washington, DC 20009
# 272    280000.0  2801 Adams Mill Rd NW APT 406, Washington, DC ...
# 273    385000.0              4551 Eads Pl NE, Washington, DC 20019
# 274    260000.0  3114 Wisconsin Ave NW APT 204, Washington, DC ...
# 275    649900.0  2123 California St NW APT C4, Washington, DC 2...
# 276   1249900.0        1217 10th St NW APT B, Washington, DC 20001
# 277    699000.0  2555 Pennsylvania Ave NW APT 810, Washington, ...
# 278    150000.0               Prospect St NW, Washington, DC 20007
# 279    895000.0            1724 Varnum St NW, Washington, DC 20011
# 280    725000.0        1201 Staples St NE #1, Washington, DC 20002
# 281    359999.0       1740 18th St NW APT T4, Washington, DC 20009
# 282    190000.0      4116 Ames St NE APT 101, Washington, DC 20019
# 283    625000.0               306 19th St NE, Washington, DC 20002
# 284    895000.0            1616 6th St NW #1, Washington, DC 20001
# 285   7495000.0            4840 Dexter St NW, Washington, DC 20007
# 286    449900.0             623 Mellon St SE, Washington, DC 20032
# 287    499900.0      1812 Vernon St NW APT 1, Washington, DC 20009
# 288    744999.0     905 S Carolina Ave SE #6, Washington, DC 20003
# 289   5495000.0                 3043 P St NW, Washington, DC 20007
# 290    179900.0        2636 Wade Rd SE APT 3, Washington, DC 20020
# 291    394000.0      2020 12th St NW APT T15, Washington, DC 20009
# 292    315000.0  1301 Delaware Ave SW APT N612, Washington, DC ...
# 293   1725000.0                  937 R St NW, Washington, DC 20001
# 294   7995000.0      3101 Chain Bridge Rd NW, Washington, DC 20016
# 295   2195000.0                 1303 R St NW, Washington, DC 20009
# 296     99900.0      14 Halley Pl SE APT 203, Washington, DC 20032
# 297    700000.0        1201 Staples St NE #3, Washington, DC 20002
# 298    569900.0           3927 14th St NW #3, Washington, DC 20011
# 299    215000.0    3900 Tunlaw Rd NW APT 501, Washington, DC 20007
# 300    499000.0      3900 Watson Pl NW #A-7C, Washington, DC 20016
# 301    565000.0  2123 California St NW APT B4, Washington, DC 2...
# 302    389997.0         2500 Q St NW APT 435, Washington, DC 20007
# 303    699500.0  1900 Kalorama Pl NW UNIT 55, Washington, DC 20009
# 304   3295000.0            3510 Macomb St NW, Washington, DC 20016
# 305    769900.0    1444 Church St NW APT 508, Washington, DC 20005
# 306    615000.0  4101 Cathedral Ave NW APT 1101, Washington, DC...
# 307    999900.0        751 Columbia Rd NW #1, Washington, DC 20001
# 308    349000.0                24 N St NW #2, Washington, DC 20001
# 309    379000.0      3601 38th St NW APT 302, Washington, DC 20016
# 310    674000.0   2126 Connecticut Ave NW #8, Washington, DC 20008
# 311    599900.0               6305 3rd St NW, Washington, DC 20011
# 312    164900.0  1440 Tuckerman St NW APT 203, Washington, DC 2...
# 313   2195000.0     1308 Rhode Island Ave NW, Washington, DC 20005
# 314    685000.0       1515 16th St NW APT 1C, Washington, DC 20036
# 315    435000.0  2022 Columbia Rd NW APT 418, Washington, DC 20009
# 316  12975000.0                 2715 N St NW, Washington, DC 20007
# 317    570000.0           2724 12th St NE #7, Washington, DC 20018
# 318    399900.0      1301 20th St NW APT 602, Washington, DC 20036
# 319    499900.0  1350 Maryland Ave NE UNIT 316, Washington, DC ...
# 320    479000.0      1211 13th St NW APT 205, Washington, DC 20005
# 321    267999.0      1657 31st St NW APT 108, Washington, DC 20007
# 322    378000.0           1306 Dexter Ter SE, Washington, DC 20020
# 323    549000.0           1313 11th St NW #7, Washington, DC 20001
# 324    860000.0                 2532 I St NW, Washington, DC 20037
# 325    799000.0  1954 Columbia Rd NW APT 201, Washington, DC 20009
# 326    689900.0           1225 11th St NW #5, Washington, DC 20001
# 327    295000.0          950 25th St NW #517, Washington, DC 20037
# 328    414998.0               3321 Dix St NE, Washington, DC 20019
# 329    819000.0              2236 12th Pl NW, Washington, DC 20009
# 330    879900.0        418 7th St SE APT 201, Washington, DC 20003
# 331    464900.0               131 R St NE #B, Washington, DC 20002
# 332    349900.0     414 Seward Sq SE APT 202, Washington, DC 20003
# 333    899900.0              2122 O St NW #2, Washington, DC 20037
# 334    174900.0  705 Brandywine St SE APT B1, Washington, DC 20032
# 335    900000.0        1778 Willard St NW #1, Washington, DC 20009
# 336   1795000.0             1328 Riggs St NW, Washington, DC 20009
# 337    675000.0    1380 Quincy St NW UNIT 3B, Washington, DC 20011
# 338    209000.0  2939 Van Ness St NW APT 703, Washington, DC 20008
# 339    179000.0         950 25th St NW #N111, Washington, DC 20037
# 340    349500.0          1520 O St NW APT T2, Washington, DC 20005
# 341    285000.0       922 24th St NW APT 813, Washington, DC 20037
# 342    750000.0              1506 Q St NW #1, Washington, DC 20009
# 343    549000.0          1281 Simms Pl NE #2, Washington, DC 20002
# 344    769000.0  700 New Hampshire Ave NW #817, Washington, DC ...
# 345    439900.0          1270 Barnaby Ter SE, Washington, DC 20032
# 346    412000.0  601 Pennsylvania Ave NW APT 302, Washington, D...
# 347    399000.0           2925 Stanton Rd SE, Washington, DC 20020
# 348    299900.0  2829 Connecticut Ave NW APT 108, Washington, D...
# 349   1649000.0        901 N Carolina Ave SE, Washington, DC 20003
# 350    925000.0  4000 Cathedral Ave NW APT 704B, Washington, DC...
# 351    399990.0  3446 Connecticut Ave NW APT 509, Washington, D...
# 352    649000.0          1615 Rosedale St NE, Washington, DC 20002
# 353    573900.0          910 M St NW APT 323, Washington, DC 20001
# 354    529900.0              5523 Hunt Pl NE, Washington, DC 20019
# 355   4750000.0                 2816 O St NW, Washington, DC 20007
# 356    399900.0    1625 Eckington Pl NE #317, Washington, DC 20002
# 357    399000.0        2023 Hillyer Pl NW #3, Washington, DC 20009
# 358   1197500.0    2014 Kalorama Rd NW APT 8, Washington, DC 20009
# 359    699900.0      1111 11th St NW APT 806, Washington, DC 20001
# 360    189000.0  4301 Massachusetts Ave NW APT 1006, Washington...
# 361    540000.0               5206 5th St NW, Washington, DC 20011
# 362    799900.0      111 Varnum St NW UNIT 3, Washington, DC 20011
# 363   1720000.0           2228 Decatur Pl NW, Washington, DC 20008
# 364    759000.0     807 Delaware Ave SW #232, Washington, DC 20024
# 365    719900.0       1932 9th St NW APT 201, Washington, DC 20001
# 366   1575000.0         3608 Reservoir Rd NW, Washington, DC 20007
# 367   3295000.0          1820 Kalorama Sq NW, Washington, DC 20008
# 368    729000.0      2717 Ontario Rd NW #102, Washington, DC 20009
# 369    189998.0     4212 Benning Rd NE APT 1, Washington, DC 20019
# 370    475000.0      1457 Park Rd NW APT 302, Washington, DC 20010
# 371    399900.0       412 19th St NE APT 102, Washington, DC 20002
# 372   1650000.0     111-113 Duddington Pl SE, Washington, DC 20003
# 373    409900.0      3629 38th St NW APT 101, Washington, DC 20016
# 374    995000.0        1665 Wisconsin Ave NW, Washington, DC 20007
# 375   1995000.0          631 Lexington Pl NE, Washington, DC 20002
# 376    360000.0          713 Croissant Pl SE, Washington, DC 20019
# 377    312000.0  4000 Cathedral Ave NW #243B, Washington, DC 20016
# 378   1150000.0      1341 Independence Ct SE, Washington, DC 20003
# 379   6995000.0                 2915 O St NW, Washington, DC 20007
# 380   2695000.0          1310 Q St NW UNIT 6, Washington, DC 20009
# 381    299000.0  3900 Cathedral Ave NW APT 201A, Washington, DC...
# 382    243000.0  4915 Nannie Helen Burroughs Ave NE APT 201, Wa...
# 383    239900.0  3618 Connecticut Ave NW APT 303, Washington, D...
# 384    975000.0  2205 California St NW APT 104, Washington, DC ...
# 385    649000.0            765 18th St NE #4, Washington, DC 20002
# 386   1250000.0             1612 Levis St NE, Washington, DC 20002
# 387   2285000.0            1827 Phelps Pl NW, Washington, DC 20008
# 388    359000.0      2535 13th St NW APT 103, Washington, DC 20009
# 389    499000.0              921 Ridge Rd SE, Washington, DC 20019
# 390    460000.0  329 Rhode Island Ave NE APT 203, Washington, D...
# 391    499000.0        2466 Ontario Rd NW #4, Washington, DC 20009
# 392    399900.0            3916 7th St NE #1, Washington, DC 20017
# 393    444900.0  3101 New Mexico Ave NW APT 854, Washington, DC...
# 394    265000.0          1330 Barnaby Ter SE, Washington, DC 20032
# 395    269495.0         2424 17th St NW #204, Washington, DC 20009
# 396    749000.0        2466 Ontario Rd NW #2, Washington, DC 20009
# 397   1795000.0                 1540 T St NW, Washington, DC 20009
# 398    500000.0     700 New Hampshire Ave NW, Washington, DC 20037
# 399   2499000.0                515 7th St SE, Washington, DC 20003
# 400    189000.0  4301 Massachusetts Ave NW APT 1006, Washington...
# 401    540000.0               5206 5th St NW, Washington, DC 20011
# 402    799900.0      111 Varnum St NW UNIT 3, Washington, DC 20011
# 403   1720000.0           2228 Decatur Pl NW, Washington, DC 20008
# 404    759000.0     807 Delaware Ave SW #232, Washington, DC 20024
# 405    719900.0       1932 9th St NW APT 201, Washington, DC 20001
# 406   1575000.0         3608 Reservoir Rd NW, Washington, DC 20007
# 407   3295000.0          1820 Kalorama Sq NW, Washington, DC 20008
# 408    729000.0      2717 Ontario Rd NW #102, Washington, DC 20009
# 409    189998.0     4212 Benning Rd NE APT 1, Washington, DC 20019
# 410    475000.0      1457 Park Rd NW APT 302, Washington, DC 20010
# 411    399900.0       412 19th St NE APT 102, Washington, DC 20002
# 412   1650000.0     111-113 Duddington Pl SE, Washington, DC 20003
# 413    409900.0      3629 38th St NW APT 101, Washington, DC 20016
# 414    995000.0        1665 Wisconsin Ave NW, Washington, DC 20007
# 415   1995000.0          631 Lexington Pl NE, Washington, DC 20002
# 416    360000.0          713 Croissant Pl SE, Washington, DC 20019
# 417    312000.0  4000 Cathedral Ave NW #243B, Washington, DC 20016
# 418   1150000.0      1341 Independence Ct SE, Washington, DC 20003
# 419   6995000.0                 2915 O St NW, Washington, DC 20007
# 420   2695000.0          1310 Q St NW UNIT 6, Washington, DC 20009
# 421    299000.0  3900 Cathedral Ave NW APT 201A, Washington, DC...
# 422    243000.0  4915 Nannie Helen Burroughs Ave NE APT 201, Wa...
# 423    239900.0  3618 Connecticut Ave NW APT 303, Washington, D...
# 424    975000.0  2205 California St NW APT 104, Washington, DC ...
# 425    649000.0            765 18th St NE #4, Washington, DC 20002
# 426   1250000.0             1612 Levis St NE, Washington, DC 20002
# 427   2285000.0            1827 Phelps Pl NW, Washington, DC 20008
# 428    359000.0      2535 13th St NW APT 103, Washington, DC 20009
# 429    499000.0              921 Ridge Rd SE, Washington, DC 20019
# 430    460000.0  329 Rhode Island Ave NE APT 203, Washington, D...
# 431    499000.0        2466 Ontario Rd NW #4, Washington, DC 20009
# 432    399900.0            3916 7th St NE #1, Washington, DC 20017
# 433    444900.0  3101 New Mexico Ave NW APT 854, Washington, DC...
# 434    265000.0          1330 Barnaby Ter SE, Washington, DC 20032
# 435    269495.0         2424 17th St NW #204, Washington, DC 20009
# 436    749000.0        2466 Ontario Rd NW #2, Washington, DC 20009
# 437   1795000.0                 1540 T St NW, Washington, DC 20009
# 438    500000.0     700 New Hampshire Ave NW, Washington, DC 20037
# 439   2499000.0                515 7th St SE, Washington, DC 20003
# 440    189000.0  4301 Massachusetts Ave NW APT 1006, Washington...
# 441    540000.0               5206 5th St NW, Washington, DC 20011
# 442    799900.0      111 Varnum St NW UNIT 3, Washington, DC 20011
# 443   1720000.0           2228 Decatur Pl NW, Washington, DC 20008
# 444    759000.0     807 Delaware Ave SW #232, Washington, DC 20024
# 445    719900.0       1932 9th St NW APT 201, Washington, DC 20001
# 446   1575000.0         3608 Reservoir Rd NW, Washington, DC 20007
# 447   3295000.0          1820 Kalorama Sq NW, Washington, DC 20008
# 448    729000.0      2717 Ontario Rd NW #102, Washington, DC 20009
# 449    189998.0     4212 Benning Rd NE APT 1, Washington, DC 20019
# 450    475000.0      1457 Park Rd NW APT 302, Washington, DC 20010
# 451    399900.0       412 19th St NE APT 102, Washington, DC 20002
# 452   1650000.0     111-113 Duddington Pl SE, Washington, DC 20003
# 453    409900.0      3629 38th St NW APT 101, Washington, DC 20016
# 454    995000.0        1665 Wisconsin Ave NW, Washington, DC 20007
# 455   1995000.0          631 Lexington Pl NE, Washington, DC 20002
# 456    360000.0          713 Croissant Pl SE, Washington, DC 20019
# 457    312000.0  4000 Cathedral Ave NW #243B, Washington, DC 20016
# 458   1150000.0      1341 Independence Ct SE, Washington, DC 20003
# 459   6995000.0                 2915 O St NW, Washington, DC 20007
# 460   2695000.0          1310 Q St NW UNIT 6, Washington, DC 20009
# 461    299000.0  3900 Cathedral Ave NW APT 201A, Washington, DC...
# 462    243000.0  4915 Nannie Helen Burroughs Ave NE APT 201, Wa...
# 463    239900.0  3618 Connecticut Ave NW APT 303, Washington, D...
# 464    975000.0  2205 California St NW APT 104, Washington, DC ...
# 465    649000.0            765 18th St NE #4, Washington, DC 20002
# 466   1250000.0             1612 Levis St NE, Washington, DC 20002
# 467   2285000.0            1827 Phelps Pl NW, Washington, DC 20008
# 468    359000.0      2535 13th St NW APT 103, Washington, DC 20009
# 469    499000.0              921 Ridge Rd SE, Washington, DC 20019
# 470    460000.0  329 Rhode Island Ave NE APT 203, Washington, D...
# 471    499000.0        2466 Ontario Rd NW #4, Washington, DC 20009
# 472    399900.0            3916 7th St NE #1, Washington, DC 20017
# 473    444900.0  3101 New Mexico Ave NW APT 854, Washington, DC...
# 474    265000.0          1330 Barnaby Ter SE, Washington, DC 20032
# 475    269495.0         2424 17th St NW #204, Washington, DC 20009
# 476    749000.0        2466 Ontario Rd NW #2, Washington, DC 20009
# 477   1795000.0                 1540 T St NW, Washington, DC 20009
# 478    500000.0     700 New Hampshire Ave NW, Washington, DC 20037
# 479   2499000.0                515 7th St SE, Washington, DC 20003
# 480    189000.0  4301 Massachusetts Ave NW APT 1006, Washington...
# 481    540000.0               5206 5th St NW, Washington, DC 20011
# 482    799900.0      111 Varnum St NW UNIT 3, Washington, DC 20011
# 483   1720000.0           2228 Decatur Pl NW, Washington, DC 20008
# 484    759000.0     807 Delaware Ave SW #232, Washington, DC 20024
# 485    719900.0       1932 9th St NW APT 201, Washington, DC 20001
# 486   1575000.0         3608 Reservoir Rd NW, Washington, DC 20007
# 487   3295000.0          1820 Kalorama Sq NW, Washington, DC 20008
# 488    729000.0      2717 Ontario Rd NW #102, Washington, DC 20009
# 489    189998.0     4212 Benning Rd NE APT 1, Washington, DC 20019
# 490    475000.0      1457 Park Rd NW APT 302, Washington, DC 20010
# 491    399900.0       412 19th St NE APT 102, Washington, DC 20002
# 492   1650000.0     111-113 Duddington Pl SE, Washington, DC 20003
# 493    409900.0      3629 38th St NW APT 101, Washington, DC 20016
# 494    995000.0        1665 Wisconsin Ave NW, Washington, DC 20007
# 495   1995000.0          631 Lexington Pl NE, Washington, DC 20002
# 496    360000.0          713 Croissant Pl SE, Washington, DC 20019
# 497    312000.0  4000 Cathedral Ave NW #243B, Washington, DC 20016
# 498   1150000.0      1341 Independence Ct SE, Washington, DC 20003
# 499   6995000.0                 2915 O St NW, Washington, DC 20007
# 500   2695000.0          1310 Q St NW UNIT 6, Washington, DC 20009
# 501    299000.0  3900 Cathedral Ave NW APT 201A, Washington, DC...
# 502    243000.0  4915 Nannie Helen Burroughs Ave NE APT 201, Wa...
# 503    239900.0  3618 Connecticut Ave NW APT 303, Washington, D...
# 504    975000.0  2205 California St NW APT 104, Washington, DC ...
# 505    649000.0            765 18th St NE #4, Washington, DC 20002
# 506   1250000.0             1612 Levis St NE, Washington, DC 20002
# 507   2285000.0            1827 Phelps Pl NW, Washington, DC 20008
# 508    359000.0      2535 13th St NW APT 103, Washington, DC 20009
# 509    499000.0              921 Ridge Rd SE, Washington, DC 20019
# 510    460000.0  329 Rhode Island Ave NE APT 203, Washington, D...
# 511    499000.0        2466 Ontario Rd NW #4, Washington, DC 20009
# 512    399900.0            3916 7th St NE #1, Washington, DC 20017
# 513    444900.0  3101 New Mexico Ave NW APT 854, Washington, DC...
# 514    265000.0          1330 Barnaby Ter SE, Washington, DC 20032
# 515    269495.0         2424 17th St NW #204, Washington, DC 20009
# 516    749000.0        2466 Ontario Rd NW #2, Washington, DC 20009
# 517   1795000.0                 1540 T St NW, Washington, DC 20009
# 518    500000.0     700 New Hampshire Ave NW, Washington, DC 20037
# 519   2499000.0                515 7th St SE, Washington, DC 20003
# 520    189000.0  4301 Massachusetts Ave NW APT 1006, Washington...
# 521    540000.0               5206 5th St NW, Washington, DC 20011
# 522    799900.0      111 Varnum St NW UNIT 3, Washington, DC 20011
# 523   1720000.0           2228 Decatur Pl NW, Washington, DC 20008
# 524    759000.0     807 Delaware Ave SW #232, Washington, DC 20024
# 525    719900.0       1932 9th St NW APT 201, Washington, DC 20001
# 526   1575000.0         3608 Reservoir Rd NW, Washington, DC 20007
# 527   3295000.0          1820 Kalorama Sq NW, Washington, DC 20008
# 528    729000.0      2717 Ontario Rd NW #102, Washington, DC 20009
# 529    189998.0     4212 Benning Rd NE APT 1, Washington, DC 20019
# 530    475000.0      1457 Park Rd NW APT 302, Washington, DC 20010
# 531    399900.0       412 19th St NE APT 102, Washington, DC 20002
# 532   1650000.0     111-113 Duddington Pl SE, Washington, DC 20003
# 533    409900.0      3629 38th St NW APT 101, Washington, DC 20016
# 534    995000.0        1665 Wisconsin Ave NW, Washington, DC 20007
# 535   1995000.0          631 Lexington Pl NE, Washington, DC 20002
# 536    360000.0          713 Croissant Pl SE, Washington, DC 20019
# 537    312000.0  4000 Cathedral Ave NW #243B, Washington, DC 20016
# 538   1150000.0      1341 Independence Ct SE, Washington, DC 20003
# 539   6995000.0                 2915 O St NW, Washington, DC 20007
# 540   2695000.0          1310 Q St NW UNIT 6, Washington, DC 20009
# 541    299000.0  3900 Cathedral Ave NW APT 201A, Washington, DC...
# 542    243000.0  4915 Nannie Helen Burroughs Ave NE APT 201, Wa...
# 543    239900.0  3618 Connecticut Ave NW APT 303, Washington, D...
# 544    975000.0  2205 California St NW APT 104, Washington, DC ...
# 545    649000.0            765 18th St NE #4, Washington, DC 20002
# 546   1250000.0             1612 Levis St NE, Washington, DC 20002
# 547   2285000.0            1827 Phelps Pl NW, Washington, DC 20008
# 548    359000.0      2535 13th St NW APT 103, Washington, DC 20009
# 549    499000.0              921 Ridge Rd SE, Washington, DC 20019
# 550    460000.0  329 Rhode Island Ave NE APT 203, Washington, D...
# 551    499000.0        2466 Ontario Rd NW #4, Washington, DC 20009
# 552    399900.0            3916 7th St NE #1, Washington, DC 20017
# 553    444900.0  3101 New Mexico Ave NW APT 854, Washington, DC...
# 554    265000.0          1330 Barnaby Ter SE, Washington, DC 20032
# 555    269495.0         2424 17th St NW #204, Washington, DC 20009
# 556    749000.0        2466 Ontario Rd NW #2, Washington, DC 20009
# 557   1795000.0                 1540 T St NW, Washington, DC 20009
# 558    500000.0     700 New Hampshire Ave NW, Washington, DC 20037
# 559   2499000.0                515 7th St SE, Washington, DC 20003
# 560    189000.0  4301 Massachusetts Ave NW APT 1006, Washington...
# 561    540000.0               5206 5th St NW, Washington, DC 20011
# 562    799900.0      111 Varnum St NW UNIT 3, Washington, DC 20011
# 563   1720000.0           2228 Decatur Pl NW, Washington, DC 20008
# 564    759000.0     807 Delaware Ave SW #232, Washington, DC 20024
# 565    719900.0       1932 9th St NW APT 201, Washington, DC 20001
# 566   1575000.0         3608 Reservoir Rd NW, Washington, DC 20007
# 567   3295000.0          1820 Kalorama Sq NW, Washington, DC 20008
# 568    729000.0      2717 Ontario Rd NW #102, Washington, DC 20009
# 569    189998.0     4212 Benning Rd NE APT 1, Washington, DC 20019
# 570    475000.0      1457 Park Rd NW APT 302, Washington, DC 20010
# 571    399900.0       412 19th St NE APT 102, Washington, DC 20002
# 572   1650000.0     111-113 Duddington Pl SE, Washington, DC 20003
# 573    409900.0      3629 38th St NW APT 101, Washington, DC 20016
# 574    995000.0        1665 Wisconsin Ave NW, Washington, DC 20007
# 575   1995000.0          631 Lexington Pl NE, Washington, DC 20002
# 576    360000.0          713 Croissant Pl SE, Washington, DC 20019
# 577    312000.0  4000 Cathedral Ave NW #243B, Washington, DC 20016
# 578   1150000.0      1341 Independence Ct SE, Washington, DC 20003
# 579   6995000.0                 2915 O St NW, Washington, DC 20007
# 580   2695000.0          1310 Q St NW UNIT 6, Washington, DC 20009
# 581    299000.0  3900 Cathedral Ave NW APT 201A, Washington, DC...
# 582    243000.0  4915 Nannie Helen Burroughs Ave NE APT 201, Wa...
# 583    239900.0  3618 Connecticut Ave NW APT 303, Washington, D...
# 584    975000.0  2205 California St NW APT 104, Washington, DC ...
# 585    649000.0            765 18th St NE #4, Washington, DC 20002
# 586   1250000.0             1612 Levis St NE, Washington, DC 20002
# 587   2285000.0            1827 Phelps Pl NW, Washington, DC 20008
# 588    359000.0      2535 13th St NW APT 103, Washington, DC 20009
# 589    499000.0              921 Ridge Rd SE, Washington, DC 20019
# 590    460000.0  329 Rhode Island Ave NE APT 203, Washington, D...
# 591    499000.0        2466 Ontario Rd NW #4, Washington, DC 20009
# 592    399900.0            3916 7th St NE #1, Washington, DC 20017
# 593    444900.0  3101 New Mexico Ave NW APT 854, Washington, DC...
# 594    265000.0          1330 Barnaby Ter SE, Washington, DC 20032
# 595    269495.0         2424 17th St NW #204, Washington, DC 20009
# 596    749000.0        2466 Ontario Rd NW #2, Washington, DC 20009
# 597   1795000.0                 1540 T St NW, Washington, DC 20009
# 598    500000.0     700 New Hampshire Ave NW, Washington, DC 20037
# 599   2499000.0                515 7th St SE, Washington, DC 20003
#
#                                                  links   beds baths     sqft  \
# 0    https://www.zillow.com/homedetails/4810-48th-S...      3     3   2500.0
# 1    https://www.zillow.com/homedetails/1323-F-St-N...      3     3   1515.0
# 2    https://www.zillow.com/homedetails/1669-Columb...      2     2   1120.0
# 3    https://www.zillow.com/homedetails/3750-Northa...      4     4   3082.0
# 4    https://www.zillow.com/homedetails/609-Marylan...      2     3   2634.0
# 5    https://www.zillow.com/homedetails/2349-King-P...      3     3   3350.0
# 6    https://www.zillow.com/homedetails/6125-32nd-S...      3     2   1758.0
# 7    https://www.zillow.com/homedetails/3301-Fessen...     11    17  17631.0
# 8    https://www.zillow.com/homedetails/1311-D-St-N...      4     2   1748.0
# 9    https://www.zillow.com/homedetails/3806-13th-S...      3     3   2535.0
# 10   https://www.zillow.com/homedetails/1715-15th-S...      2     2   1002.0
# 11   https://www.zillow.com/homedetails/4721-1st-St...      2     1    717.0
# 12   https://www.zillow.com/homedetails/3008-K-St-S...      3     2   1302.0
# 13   https://www.zillow.com/homedetails/337-6th-St-...      4     3   2391.0
# 14   https://www.zillow.com/homedetails/5119-Bass-P...      2     2   1452.0
# 15   https://www.zillow.com/homedetails/3315-B-St-S...      4     3   1800.0
# 16   https://www.zillow.com/homedetails/503-D-St-SE...      3     1   1494.0
# 17   https://www.zillow.com/homedetails/1917-9-1-2-...      3     2   1260.0
# 18   https://www.zillow.com/homedetails/612-Eastern...      3     2   1317.0
# 19   https://www.zillow.com/homedetails/2010-Jackso...      4     4   1526.0
# 20   https://www.zillow.com/homedetails/4809-V-St-N...      4     3   2366.0
# 21   https://www.zillow.com/homedetails/3205-Georgi...      2     1    667.0
# 22   https://www.zillow.com/homedetails/3036-Woodla...      8    11  10823.0
# 23   https://www.zillow.com/homedetails/1652-Fort-D...      4     2   1536.0
# 24   https://www.zillow.com/homedetails/4650-Hayes-...      3     3   1054.0
# 25   https://www.zillow.com/homedetails/1407-Oak-St...      3     4   2160.0
# 26   https://www.zillow.com/homedetails/513-14th-St...      3     2   1374.0
# 27   https://www.zillow.com/homedetails/3011-Dent-P...      3     2   2300.0
# 28   https://www.zillow.com/homedetails/404-Constit...      4     3   2369.0
# 29   https://www.zillow.com/homedetails/1835-E-St-N...      3     2   1546.0
# 30   https://www.zillow.com/homedetails/353-O-St-SW...      3     2   1595.0
# 31   https://www.zillow.com/homedetails/2131-Suitla...      2     1    824.0
# 32   https://www.zillow.com/homedetails/1929-1st-St...      1     1    525.0
# 33   https://www.zillow.com/homedetails/5105-Just-S...      3     2    810.0
# 34   https://www.zillow.com/homedetails/3314-Ordway...      3     4   3700.0
# 35   https://www.zillow.com/homedetails/712-C-St-NE...      3     3   1764.0
# 36   https://www.zillow.com/homedetails/625-Chesape...      2     1    768.0
# 37   https://www.zillow.com/homedetails/1311-Delawa...      2     3   1350.0
# 38   https://www.zillow.com/homedetails/108-Tenness...      2     1    850.0
# 39   https://www.zillow.com/homedetails/1432-Ridge-...      3     2   1776.0
# 40   https://www.zillow.com/homedetails/2507-Foxhal...      3     3   2500.0
# 41   https://www.zillow.com/homedetails/2019-5th-St...      3     3   1515.0
# 42   https://www.zillow.com/homedetails/725-Atlanti...      2     2   1120.0
# 43   https://www.zillow.com/homedetails/1906-4th-St...      4     4   3082.0
# 44   https://www.zillow.com/homedetails/1000-New-Je...      2     3   2634.0
# 45   https://www.zillow.com/homedetails/3812-Hansbe...      3     3   3350.0
# 46   https://www.zillow.com/homedetails/83-P-St-NW-...      3     2   1758.0
# 47   https://www.zillow.com/homedetails/5800-Oregon...     11    17  17631.0
# 48   https://www.zillow.com/homedetails/3069-Canal-...      4     2   1748.0
# 49   https://www.zillow.com/homedetails/1660-W-Virg...      3     3   2535.0
# 50   https://www.zillow.com/homedetails/1011-18th-S...      2     2   1002.0
# 51   https://www.zillow.com/homedetails/4331-Dubois...      2     1    717.0
# 52   https://www.zillow.com/homedetails/3401-Massac...      3     2   1302.0
# 53   https://www.zillow.com/homedetails/1601-5th-St...      4     3   2391.0
# 54   https://www.zillow.com/homedetails/610-Nichols...      2     2   1452.0
# 55   https://www.zillow.com/homedetails/4019-Mansio...      4     3   1800.0
# 56   https://www.zillow.com/homedetails/3129-N-St-N...      3     1   1494.0
# 57   https://www.zillow.com/homedetails/1808-Belmon...      3     2   1260.0
# 58   https://www.zillow.com/homedetails/314-5th-St-...      3     2   1317.0
# 59   https://www.zillow.com/homedetails/4615-Dexter...      4     4   1526.0
# 60   https://www.zillow.com/homedetails/2330-Payne-...      4     3   2366.0
# 61   https://www.zillow.com/homedetails/5032-1-2-Da...      2     1    667.0
# 62   https://www.zillow.com/homedetails/3906-1st-St...      8    11  10823.0
# 63   https://www.zillow.com/homedetails/4400-Garfie...      4     2   1536.0
# 64   https://www.zillow.com/homedetails/2503-Chain-...      3     3   1054.0
# 65   https://www.zillow.com/homedetails/3537-T-St-N...      3     4   2160.0
# 66   https://www.zillow.com/homedetails/442-M-St-NW...      3     2   1374.0
# 67   https://www.zillow.com/homedetails/3117-Georgi...      3     2   2300.0
# 68   https://www.zillow.com/homedetails/3129-Newton...      4     3   2369.0
# 69   https://www.zillow.com/homedetails/4000-Cathed...      3     2   1546.0
# 70   https://www.zillow.com/homedetails/4849-Rodman...      3     2   1595.0
# 71   https://www.zillow.com/homedetails/368-Burbank...      2     1    824.0
# 72   https://www.zillow.com/homedetails/213-6th-St-...      1     1    525.0
# ...
# 387                           1827 Phelps Pl NW  Washington    DC  20008
# 388                     2535 13th St NW APT 103  Washington    DC  20009
# 389                             921 Ridge Rd SE  Washington    DC  20019
# 390             329 Rhode Island Ave NE APT 203  Washington    DC  20002
# 391                       2466 Ontario Rd NW #4  Washington    DC  20009
# 392                           3916 7th St NE #1  Washington    DC  20017
# 393              3101 New Mexico Ave NW APT 854  Washington    DC  20016
# 394                         1330 Barnaby Ter SE  Washington    DC  20032
# 395                        2424 17th St NW #204  Washington    DC  20009
# 396                       2466 Ontario Rd NW #2  Washington    DC  20009
# 397                                1540 T St NW  Washington    DC  20009
# 398                    700 New Hampshire Ave NW  Washington    DC  20037
# 399                               515 7th St SE  Washington    DC  20003
# 400          4301 Massachusetts Ave NW APT 1006  Washington    DC  20016
# 401                              5206 5th St NW  Washington    DC  20011
# 402                     111 Varnum St NW UNIT 3  Washington    DC  20011
# 403                          2228 Decatur Pl NW  Washington    DC  20008
# 404                    807 Delaware Ave SW #232  Washington    DC  20024
# 405                      1932 9th St NW APT 201  Washington    DC  20001
# 406                        3608 Reservoir Rd NW  Washington    DC  20007
# 407                         1820 Kalorama Sq NW  Washington    DC  20008
# 408                     2717 Ontario Rd NW #102  Washington    DC  20009
# 409                    4212 Benning Rd NE APT 1  Washington    DC  20019
# 410                     1457 Park Rd NW APT 302  Washington    DC  20010
# 411                      412 19th St NE APT 102  Washington    DC  20002
# 412                    111-113 Duddington Pl SE  Washington    DC  20003
# 413                     3629 38th St NW APT 101  Washington    DC  20016
# 414                       1665 Wisconsin Ave NW  Washington    DC  20007
# 415                         631 Lexington Pl NE  Washington    DC  20002
# 416                         713 Croissant Pl SE  Washington    DC  20019
# 417                 4000 Cathedral Ave NW #243B  Washington    DC  20016
# 418                     1341 Independence Ct SE  Washington    DC  20003
# 419                                2915 O St NW  Washington    DC  20007
# 420                         1310 Q St NW UNIT 6  Washington    DC  20009
# 421              3900 Cathedral Ave NW APT 201A  Washington    DC  20016
# 422  4915 Nannie Helen Burroughs Ave NE APT 201  Washington    DC  20019
# 423             3618 Connecticut Ave NW APT 303  Washington    DC  20008
# 424               2205 California St NW APT 104  Washington    DC  20008
# 425                           765 18th St NE #4  Washington    DC  20002
# 426                            1612 Levis St NE  Washington    DC  20002
# 427                           1827 Phelps Pl NW  Washington    DC  20008
# 428                     2535 13th St NW APT 103  Washington    DC  20009
# 429                             921 Ridge Rd SE  Washington    DC  20019
# 430             329 Rhode Island Ave NE APT 203  Washington    DC  20002
# 431                       2466 Ontario Rd NW #4  Washington    DC  20009
# 432                           3916 7th St NE #1  Washington    DC  20017
# 433              3101 New Mexico Ave NW APT 854  Washington    DC  20016
# 434                         1330 Barnaby Ter SE  Washington    DC  20032
# 435                        2424 17th St NW #204  Washington    DC  20009
# 436                       2466 Ontario Rd NW #2  Washington    DC  20009
# 437                                1540 T St NW  Washington    DC  20009
# 438                    700 New Hampshire Ave NW  Washington    DC  20037
# 439                               515 7th St SE  Washington    DC  20003
# 440          4301 Massachusetts Ave NW APT 1006  Washington    DC  20016
# 441                              5206 5th St NW  Washington    DC  20011
# 442                     111 Varnum St NW UNIT 3  Washington    DC  20011
# 443                          2228 Decatur Pl NW  Washington    DC  20008
# 444                    807 Delaware Ave SW #232  Washington    DC  20024
# 445                      1932 9th St NW APT 201  Washington    DC  20001
# 446                        3608 Reservoir Rd NW  Washington    DC  20007
# 447                         1820 Kalorama Sq NW  Washington    DC  20008
# 448                     2717 Ontario Rd NW #102  Washington    DC  20009
# 449                    4212 Benning Rd NE APT 1  Washington    DC  20019
# 450                     1457 Park Rd NW APT 302  Washington    DC  20010
# 451                      412 19th St NE APT 102  Washington    DC  20002
# 452                    111-113 Duddington Pl SE  Washington    DC  20003
# 453                     3629 38th St NW APT 101  Washington    DC  20016
# 454                       1665 Wisconsin Ave NW  Washington    DC  20007
# 455                         631 Lexington Pl NE  Washington    DC  20002
# 456                         713 Croissant Pl SE  Washington    DC  20019
# 457                 4000 Cathedral Ave NW #243B  Washington    DC  20016
# 458                     1341 Independence Ct SE  Washington    DC  20003
# 459                                2915 O St NW  Washington    DC  20007
# 460                         1310 Q St NW UNIT 6  Washington    DC  20009
# 461              3900 Cathedral Ave NW APT 201A  Washington    DC  20016
# 462  4915 Nannie Helen Burroughs Ave NE APT 201  Washington    DC  20019
# 463             3618 Connecticut Ave NW APT 303  Washington    DC  20008
# 464               2205 California St NW APT 104  Washington    DC  20008
# 465                           765 18th St NE #4  Washington    DC  20002
# 466                            1612 Levis St NE  Washington    DC  20002
# 467                           1827 Phelps Pl NW  Washington    DC  20008
# 468                     2535 13th St NW APT 103  Washington    DC  20009
# 469                             921 Ridge Rd SE  Washington    DC  20019
# 470             329 Rhode Island Ave NE APT 203  Washington    DC  20002
# 471                       2466 Ontario Rd NW #4  Washington    DC  20009
# 472                           3916 7th St NE #1  Washington    DC  20017
# 473              3101 New Mexico Ave NW APT 854  Washington    DC  20016
# 474                         1330 Barnaby Ter SE  Washington    DC  20032
# 475                        2424 17th St NW #204  Washington    DC  20009
# 476                       2466 Ontario Rd NW #2  Washington    DC  20009
# 477                                1540 T St NW  Washington    DC  20009
# 478                    700 New Hampshire Ave NW  Washington    DC  20037
# 479                               515 7th St SE  Washington    DC  20003
# 480          4301 Massachusetts Ave NW APT 1006  Washington    DC  20016
# 481                              5206 5th St NW  Washington    DC  20011
# 482                     111 Varnum St NW UNIT 3  Washington    DC  20011
# 483                          2228 Decatur Pl NW  Washington    DC  20008
# 484                    807 Delaware Ave SW #232  Washington    DC  20024
# 485                      1932 9th St NW APT 201  Washington    DC  20001
# 486                        3608 Reservoir Rd NW  Washington    DC  20007
# 487                         1820 Kalorama Sq NW  Washington    DC  20008
# 488                     2717 Ontario Rd NW #102  Washington    DC  20009
# 489                    4212 Benning Rd NE APT 1  Washington    DC  20019
# 490                     1457 Park Rd NW APT 302  Washington    DC  20010
# 491                      412 19th St NE APT 102  Washington    DC  20002
# 492                    111-113 Duddington Pl SE  Washington    DC  20003
# 493                     3629 38th St NW APT 101  Washington    DC  20016
# 494                       1665 Wisconsin Ave NW  Washington    DC  20007
# 495                         631 Lexington Pl NE  Washington    DC  20002
# 496                         713 Croissant Pl SE  Washington    DC  20019
# 497                 4000 Cathedral Ave NW #243B  Washington    DC  20016
# 498                     1341 Independence Ct SE  Washington    DC  20003
# 499                                2915 O St NW  Washington    DC  20007
# 500                         1310 Q St NW UNIT 6  Washington    DC  20009
# 501              3900 Cathedral Ave NW APT 201A  Washington    DC  20016
# 502  4915 Nannie Helen Burroughs Ave NE APT 201  Washington    DC  20019
# 503             3618 Connecticut Ave NW APT 303  Washington    DC  20008
# 504               2205 California St NW APT 104  Washington    DC  20008
# 505                           765 18th St NE #4  Washington    DC  20002
# 506                            1612 Levis St NE  Washington    DC  20002
# 507                           1827 Phelps Pl NW  Washington    DC  20008
# 508                     2535 13th St NW APT 103  Washington    DC  20009
# 509                             921 Ridge Rd SE  Washington    DC  20019
# 510             329 Rhode Island Ave NE APT 203  Washington    DC  20002
# 511                       2466 Ontario Rd NW #4  Washington    DC  20009
# 512                           3916 7th St NE #1  Washington    DC  20017
# 513              3101 New Mexico Ave NW APT 854  Washington    DC  20016
# 514                         1330 Barnaby Ter SE  Washington    DC  20032
# 515                        2424 17th St NW #204  Washington    DC  20009
# 516                       2466 Ontario Rd NW #2  Washington    DC  20009
# 517                                1540 T St NW  Washington    DC  20009
# 518                    700 New Hampshire Ave NW  Washington    DC  20037
# 519                               515 7th St SE  Washington    DC  20003
# 520          4301 Massachusetts Ave NW APT 1006  Washington    DC  20016
# 521                              5206 5th St NW  Washington    DC  20011
# 522                     111 Varnum St NW UNIT 3  Washington    DC  20011
# 523                          2228 Decatur Pl NW  Washington    DC  20008
# 524                    807 Delaware Ave SW #232  Washington    DC  20024
# 525                      1932 9th St NW APT 201  Washington    DC  20001
# 526                        3608 Reservoir Rd NW  Washington    DC  20007
# 527                         1820 Kalorama Sq NW  Washington    DC  20008
# 528                     2717 Ontario Rd NW #102  Washington    DC  20009
# 529                    4212 Benning Rd NE APT 1  Washington    DC  20019
# 530                     1457 Park Rd NW APT 302  Washington    DC  20010
# 531                      412 19th St NE APT 102  Washington    DC  20002
# 532                    111-113 Duddington Pl SE  Washington    DC  20003
# 533                     3629 38th St NW APT 101  Washington    DC  20016
# 534                       1665 Wisconsin Ave NW  Washington    DC  20007
# 535                         631 Lexington Pl NE  Washington    DC  20002
# 536                         713 Croissant Pl SE  Washington    DC  20019
# 537                 4000 Cathedral Ave NW #243B  Washington    DC  20016
# 538                     1341 Independence Ct SE  Washington    DC  20003
# 539                                2915 O St NW  Washington    DC  20007
# 540                         1310 Q St NW UNIT 6  Washington    DC  20009
# 541              3900 Cathedral Ave NW APT 201A  Washington    DC  20016
# 542  4915 Nannie Helen Burroughs Ave NE APT 201  Washington    DC  20019
# 543             3618 Connecticut Ave NW APT 303  Washington    DC  20008
# 544               2205 California St NW APT 104  Washington    DC  20008
# 545                           765 18th St NE #4  Washington    DC  20002
# 546                            1612 Levis St NE  Washington    DC  20002
# 547                           1827 Phelps Pl NW  Washington    DC  20008
# 548                     2535 13th St NW APT 103  Washington    DC  20009
# 549                             921 Ridge Rd SE  Washington    DC  20019
# 550             329 Rhode Island Ave NE APT 203  Washington    DC  20002
# 551                       2466 Ontario Rd NW #4  Washington    DC  20009
# 552                           3916 7th St NE #1  Washington    DC  20017
# 553              3101 New Mexico Ave NW APT 854  Washington    DC  20016
# 554                         1330 Barnaby Ter SE  Washington    DC  20032
# 555                        2424 17th St NW #204  Washington    DC  20009
# 556                       2466 Ontario Rd NW #2  Washington    DC  20009
# 557                                1540 T St NW  Washington    DC  20009
# 558                    700 New Hampshire Ave NW  Washington    DC  20037
# 559                               515 7th St SE  Washington    DC  20003
# 560          4301 Massachusetts Ave NW APT 1006  Washington    DC  20016
# 561                              5206 5th St NW  Washington    DC  20011
# 562                     111 Varnum St NW UNIT 3  Washington    DC  20011
# 563                          2228 Decatur Pl NW  Washington    DC  20008
# 564                    807 Delaware Ave SW #232  Washington    DC  20024
# 565                      1932 9th St NW APT 201  Washington    DC  20001
# 566                        3608 Reservoir Rd NW  Washington    DC  20007
# 567                         1820 Kalorama Sq NW  Washington    DC  20008
# 568                     2717 Ontario Rd NW #102  Washington    DC  20009
# 569                    4212 Benning Rd NE APT 1  Washington    DC  20019
# 570                     1457 Park Rd NW APT 302  Washington    DC  20010
# 571                      412 19th St NE APT 102  Washington    DC  20002
# 572                    111-113 Duddington Pl SE  Washington    DC  20003
# 573                     3629 38th St NW APT 101  Washington    DC  20016
# 574                       1665 Wisconsin Ave NW  Washington    DC  20007
# 575                         631 Lexington Pl NE  Washington    DC  20002
# 576                         713 Croissant Pl SE  Washington    DC  20019
# 577                 4000 Cathedral Ave NW #243B  Washington    DC  20016
# 578                     1341 Independence Ct SE  Washington    DC  20003
# 579                                2915 O St NW  Washington    DC  20007
# 580                         1310 Q St NW UNIT 6  Washington    DC  20009
# 581              3900 Cathedral Ave NW APT 201A  Washington    DC  20016
# 582  4915 Nannie Helen Burroughs Ave NE APT 201  Washington    DC  20019
# 583             3618 Connecticut Ave NW APT 303  Washington    DC  20008
# 584               2205 California St NW APT 104  Washington    DC  20008
# 585                           765 18th St NE #4  Washington    DC  20002
# 586                            1612 Levis St NE  Washington    DC  20002
# 587                           1827 Phelps Pl NW  Washington    DC  20008
# 588                     2535 13th St NW APT 103  Washington    DC  20009
# 589                             921 Ridge Rd SE  Washington    DC  20019
# 590             329 Rhode Island Ave NE APT 203  Washington    DC  20002
# 591                       2466 Ontario Rd NW #4  Washington    DC  20009
# 592                           3916 7th St NE #1  Washington    DC  20017
# 593              3101 New Mexico Ave NW APT 854  Washington    DC  20016
# 594                         1330 Barnaby Ter SE  Washington    DC  20032
# 595                        2424 17th St NW #204  Washington    DC  20009
# 596                       2466 Ontario Rd NW #2  Washington    DC  20009
# 597                                1540 T St NW  Washington    DC  20009
# 598                    700 New Hampshire Ave NW  Washington    DC  20037
# 599                               515 7th St SE  Washington    DC  20003

# %%
# Export data to excel file
df.to_excel('StateData/washintondc.xlsx', index = False)

# %% [markdown]
# ### State list
# - Alabama ////////////
# - Alaska /////////////
# - Arizona ////////////
# - Arkansas ///////////
# - California //////////
# - Colorado //////////
# - Connecticut //////////
# - Delaware //////////
# - Florida //////////
# - Georgia //////////
# - Hawaii //////////
# - Idaho //////////
# - Illinois //////////
# - Indiana //////////
# - Iowa //////////
# - Kansas ///////////
# - Kentucky ///////////
# - Louisiana ///////////
# - Maine ///////////
# - Maryland ///////////
# - Massachusetts ///////////
# - Michigan ///////////
# - Minnesota ///////////
# - Mississippi ///////////
# - Missouri /////////
# - Montana /////////
# - Nebraska /////////
# - Nevada /////////
# - New Hampshire /////////
# - New Jersey /////////
# - New Mexico /////////
# - New York /////////
# - North Carolina /////////
# - North Dakota /////////
# - Ohio /////////
# - Oklahoma /////////
# - Oregon /////////
# - Pennsylvania //////////
# - Rhode Island //////////
# - South Carolina /////////
# - South Dakota /////////
# - Tennessee /////////
# - Texas ////////////
# - Utah ////////////
# - Vermont ////////////
# - Virginia ////////////
# - Washington ////////////
# - West Virginia ////////////
# - Wisconsin /////////
# - Wyoming /////////
# - Washington D.C. /////////
