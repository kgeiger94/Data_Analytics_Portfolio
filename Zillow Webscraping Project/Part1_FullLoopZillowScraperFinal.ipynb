# %% [markdown]
# # <center>Zillow Webscraping Project<center>

# %% [markdown]
# ## Project Details:
# In this project, I will utilize BeautifulSoup to web scrape and collect Zillow housing data from multiple listing pages. The purpose of this project is to collect housing data for every state in the United States. For this project, I will attempt to collect around 600 house listings for each state to have roughly 30,000 house listings combined. 600 house listings from each state should ensure that enough data is collected to perform accurate data analysis.
#
# *Note: This dataset will be used as a sample of house data in each state with only a small amount of Zillow listings being scraped
#
# ## Data Collection and Wrangling:
# I will attempt to collect
# - House Price
# - House Address
# - House Beds, Baths, and SqFt
# - House URL/Link to Zillow
#
# ## Project Goals:
# - Collect 600 house listings per U.S. state using BeautifulSoup for web scraping
# - Perform Exploratory Data Analysis with the housing data
# - Create a dynamic dashboard that can be used to search house listings and analyze housing data by state
#
# *Note: This code will require it to be ran one time for each state. When all housing data for each state has been scraped, all dataframes will be appended to create the final master dataset that will be used for EDA and the Power BI dashboard.
#
# ## Project Parts:
# - Part One - BeautifulSoup webs craping of Zillow house listings for each U.S. State
# - Part Two - Append all scraped and collected datasets from each state into one master dataset
# - Part Three - Exploratory Data Analysis of Zillow house listings from all 50 states
# - Part Four - Build a dynamic BI dashboard to search house listings and analyze housing data in all 50 states

# %% [markdown]
# # <center>Part One: Scraping Zillow House Listings<center>

# %% [markdown]
# ## Import Needed Python Packages

# %%
# Packages
import pandas as pd
import numpy as np

import requests
import os
import time
import sys
from IPython import display
from IPython.display import Image

import regex as re
import prettify
import numbers
import htmltext

import lxml
from lxml.html.soupparser import fromstring

from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %% [markdown]
# ## BeautifulSoup Webscraping/Data Collection

# %%
# Add headers to keep from getting capthas returns from Zillow
req_headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'en-US,en;q=0.8',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'
}

# %%
# Create variables for all pages of Zillow that will be looped
# About 15 pages will be looped to collect 600 listings per state (Zillow has about 40 listings per page)

with requests.Session() as s:
    scrapingstate = 'kansas/' #*--Change state to scrape house listings--*
    
    Page = 'https://www.zillow.com/homes/for_sale/'+scrapingstate
    Page2 = 'https://www.zillow.com/homes/for_sale/'+scrapingstate+'/2_p/'
    Page3 = 'https://www.zillow.com/homes/for_sale/'+scrapingstate+'/3_p/'
    Page4 = 'https://www.zillow.com/homes/for_sale/'+scrapingstate+'/4_p/'
    Page5 = 'https://www.zillow.com/homes/for_sale/'+scrapingstate+'/5_p/'
    Page6 = 'https://www.zillow.com/homes/for_sale/'+scrapingstate+'/6_p/'
    Page7 = 'https://www.zillow.com/homes/for_sale/'+scrapingstate+'/7_p/'
    Page8 = 'https://www.zillow.com/homes/for_sale/'+scrapingstate+'/8_p/'
    Page9 = 'https://www.zillow.com/homes/for_sale/'+scrapingstate+'/9_p/'
    Page10 = 'https://www.zillow.com/homes/for_sale/'+scrapingstate+'/10_p/'
    Page11 = 'https://www.zillow.com/homes/for_sale/'+scrapingstate+'/11_p/'
    Page12 = 'https://www.zillow.com/homes/for_sale/'+scrapingstate+'/12_p/'
    Page13 = 'https://www.zillow.com/homes/for_sale/'+scrapingstate+'/13_p/'
    Page14 = 'https://www.zillow.com/homes/for_sale/'+scrapingstate+'/14_p/'
    Page15 = 'https://www.zillow.com/homes/for_sale/'+scrapingstate+'/15_p/'

    r = s.get(Page, headers=req_headers)
    r2 = s.get(Page2, headers=req_headers)
    r3 = s.get(Page3, headers=req_headers)
    r4 = s.get(Page4, headers=req_headers)
    r5 = s.get(Page5, headers=req_headers)
    r6 = s.get(Page6, headers=req_headers)
    r7 = s.get(Page7, headers=req_headers)
    r8 = s.get(Page8, headers=req_headers)
    r9 = s.get(Page9, headers=req_headers)
    r10 = s.get(Page10, headers=req_headers)
    r11 = s.get(Page11, headers=req_headers)
    r12 = s.get(Page12, headers=req_headers)
    r13 = s.get(Page13, headers=req_headers)
    r14 = s.get(Page14, headers=req_headers)
    r15 = s.get(Page15, headers=req_headers)
    
    url_links = [Page, Page2, Page3, Page4, Page5, Page6, Page7, Page8, Page9, Page10, Page11, Page12, Page13, Page14, Page15]

# %%
# Now add the contents from urls to soup variables of each url
soup = BeautifulSoup(r.content, 'html.parser')
soup1 = BeautifulSoup(r2.content, 'html.parser')
soup2 = BeautifulSoup(r3.content, 'html.parser')
soup3 = BeautifulSoup(r4.content, 'html.parser')
soup4 = BeautifulSoup(r5.content, 'html.parser')
soup5 = BeautifulSoup(r6.content, 'html.parser')
soup6 = BeautifulSoup(r7.content, 'html.parser')
soup7 = BeautifulSoup(r8.content, 'html.parser')
soup8 = BeautifulSoup(r9.content, 'html.parser')
soup9 = BeautifulSoup(r10.content, 'html.parser')
soup10 = BeautifulSoup(r10.content, 'html.parser')
soup11 = BeautifulSoup(r10.content, 'html.parser')
soup12 = BeautifulSoup(r10.content, 'html.parser')
soup13 = BeautifulSoup(r10.content, 'html.parser')
soup14 = BeautifulSoup(r10.content, 'html.parser')

# %% [markdown]
# ### Page 1 Loop

# %%
# Create first datarame for first page of Zillow
df = pd.DataFrame()

# Create loop that pulls each specified variable
for i in soup:
    address = soup.find_all (class_= 'list-card-addr')
    price = list(soup.find_all (class_='list-card-price'))
    details = list(soup.find_all("ul", class_="list-card-details"))    
    
# Create columns for dataframe
df['prices'] = price
df['address'] = address
df['details'] = details

# Create an empty url list
urls = []
# Now Loop through the url and pull the href and strip out the address tag
for link in soup.find_all("article"):
    href = link.find('a',class_="list-card-link")
    addresses = href.find('address')
    addresses.extract()
    urls.append(href)

# %%
# Import the urls into a column called links
df['links'] = urls
df['links'] = df['links'].astype('str')

# %% [markdown]
# ### Page 2 Loop

# %%
# Create the second datarame for second page of Zillow
df1 = pd.DataFrame()

for i in soup1:
    address1 = soup1.find_all (class_= 'list-card-addr')
    price1 = list(soup1.find_all (class_='list-card-price'))
    details1 = list(soup.find_all("ul", class_="list-card-details"))
            

df1['prices'] = price1
df1['address'] = address1
df1['details'] = details1


urls = []

for link in soup1.find_all("article"):
    href = link.find('a',class_="list-card-link")
    addresses = href.find('address')
    addresses.extract()
    urls.append(href)

# %%
# Import the urls into a column called links
df1['links'] = urls
df1['links'] = df1['links'].astype('str')

# %% [markdown]
# ### <center>Append the first two dataframes to ensure that scraping and looping are working<center>

# %%
# Append
df = df.append(df1, ignore_index = True)

# %%
# Show top 5 rows
df.head()
# Out:
#        prices                                    address  \
# 0  [$322,500]     [13495 Wildridge Dr, Wamego, KS 66547]
# 1  [$499,000]  [4020 W 96th St, Overland Park, KS 66207]
# 2    [$5,000]          [1414 Main St, Jetmore, KS 67854]
# 3  [$179,000]      [8932 W 17th St N, Wichita, KS 67212]
# 4  [$129,500]         [120 S 1st St, Sterling, KS 67579]
#
#                                              details  \
# 0  [[4, [ ,  , bds]], [3, [ ,  , ba]], [2,164, [ ...
# 1  [[3, [ ,  , bds]], [4, [ ,  , ba]], [3,444, [ ...
# 2  [[2, [ ,  , bds]], [2, [ ,  , ba]], [1,171, [ ...
# 3  [[3, [ ,  , bds]], [2, [ ,  , ba]], [2,556, [ ...
# 4  [[4, [ ,  , bds]], [1, [ ,  , ba]], [1,381, [ ...
#
#                                                links
# 0  <a class="list-card-link list-card-link-top-ma...
# 1  <a class="list-card-link list-card-link-top-ma...
# 2  <a class="list-card-link list-card-link-top-ma...
# 3  <a class="list-card-link list-card-link-top-ma...
# 4  <a class="list-card-link list-card-link-top-ma...

# %%
# See number of rows collected so far on 2 pages
# *Note: Each page on zillow contains between 35-40 house listings
len(df)
# Out:
# 80

# %% [markdown]
# ### <center>Scraping and looping appear to be working with 80 houses collected from page 1 and page 2<center>

# %%
# Now create the other empty dataframes for each page to keep from having to declare before each loop
df2 = pd.DataFrame()
df3 = pd.DataFrame()
df4 = pd.DataFrame()
df5 = pd.DataFrame()
df6 = pd.DataFrame()
df7 = pd.DataFrame()
df8 = pd.DataFrame()
df9 = pd.DataFrame()
df10 = pd.DataFrame()
df11 = pd.DataFrame()
df12 = pd.DataFrame()
df13 = pd.DataFrame()
df14 = pd.DataFrame()

# %% [markdown]
# ### Page 3 Loop

# %%
for i in soup2:
    address2 = soup2.find_all (class_= 'list-card-addr')
    price2 = list(soup2.find_all (class_='list-card-price'))
    details2 = list(soup2.find_all("ul", class_="list-card-details"))
            

df2['prices'] = price2
df2['address'] = address2
df2['details'] = details2


urls = []

for link in soup2.find_all("article"):
    href = link.find('a',class_="list-card-link")
    addresses = href.find('address')
    addresses.extract()
    urls.append(href)

# %%
# Import the urls into a column called links
df2['links'] = urls
df2['links'] = df2['links'].astype('str')

# %%
len(df2)
# Out:
# 40

# %% [markdown]
# ### Page 4 Loop

# %%
for i in soup3:
    address3 = soup3.find_all (class_= 'list-card-addr')
    price3 = list(soup3.find_all (class_='list-card-price'))
    details3 = list(soup3.find_all("ul", class_="list-card-details"))
            

df3['prices'] = price3
df3['address'] = address3
df3['details'] = details3


urls = []

for link in soup3.find_all("article"):
    href = link.find('a',class_="list-card-link")
    addresses = href.find('address')
    addresses.extract()
    urls.append(href)

# %%
# Import the urls into a column called links
df3['links'] = urls
df3['links'] = df3['links'].astype('str')

# %%
len(df3)
# Out:
# 40

# %% [markdown]
# ### Page 5 Loop

# %%
for i in soup4:
    address4 = soup4.find_all (class_= 'list-card-addr')
    price4 = list(soup4.find_all (class_='list-card-price'))
    details4 = list(soup4.find_all("ul", class_="list-card-details"))
            

df4['prices'] = price4
df4['address'] = address4
df4['details'] = details4


urls = []

for link in soup4.find_all("article"):
    href = link.find('a',class_="list-card-link")
    addresses = href.find('address')
    addresses.extract()
    urls.append(href)

# %%
# Import the urls into a column called links
df4['links'] = urls
df4['links'] = df4['links'].astype('str')

# %%
len(df4)
# Out:
# 40

# %% [markdown]
# ### Page 6 Loop

# %%
for i in soup5:
    address5 = soup5.find_all (class_= 'list-card-addr')
    price5 = list(soup5.find_all (class_='list-card-price'))
    details5 = list(soup5.find_all("ul", class_="list-card-details"))
            

df5['prices'] = price5
df5['address'] = address5
df5['details'] = details5


urls = []

for link in soup5.find_all("article"):
    href = link.find('a',class_="list-card-link")
    addresses = href.find('address')
    addresses.extract()
    urls.append(href)

# %%
# Import the urls into a column called links
df5['links'] = urls
df5['links'] = df5['links'].astype('str')

# %%
len(df5)
# Out:
# 40

# %% [markdown]
# ### Page 7 Loop

# %%
for i in soup6:
    address6 = soup6.find_all (class_= 'list-card-addr')
    price6 = list(soup6.find_all (class_='list-card-price'))
    details6 = list(soup6.find_all("ul", class_="list-card-details"))
            

df6['prices'] = price6
df6['address'] = address6
df6['details'] = details6


urls = []

for link in soup6.find_all("article"):
    href = link.find('a',class_="list-card-link")
    addresses = href.find('address')
    addresses.extract()
    urls.append(href)

# %%
# Import the urls into a column called links
df6['links'] = urls
df6['links'] = df6['links'].astype('str')

# %%
len(df6)
# Out:
# 40

# %% [markdown]
# ### Page 8 Loop

# %%
for i in soup7:
    address7 = soup7.find_all (class_= 'list-card-addr')
    price7 = list(soup7.find_all (class_='list-card-price'))
    details7 = list(soup7.find_all("ul", class_="list-card-details"))
            

df7['prices'] = price7
df7['address'] = address7
df7['details'] = details7


urls = []

for link in soup7.find_all("article"):
    href = link.find('a',class_="list-card-link")
    addresses = href.find('address')
    addresses.extract()
    urls.append(href)

# %%
# Import the urls into a column called links
df7['links'] = urls
df7['links'] = df7['links'].astype('str')

# %%
len(df7)
# Out:
# 40

# %% [markdown]
# ### Page 9 Loop

# %%
for i in soup8:
    address8 = soup8.find_all (class_= 'list-card-addr')
    price8 = list(soup8.find_all (class_='list-card-price'))
    details8 = list(soup8.find_all("ul", class_="list-card-details"))
            

df8['prices'] = price8
df8['address'] = address8
df8['details'] = details8


urls = []

for link in soup8.find_all("article"):
    href = link.find('a',class_="list-card-link")
    addresses = href.find('address')
    addresses.extract()
    urls.append(href)

# %%
# Import the urls into a column called links
df8['links'] = urls
df8['links'] = df8['links'].astype('str')

# %%
len(df8)
# Out:
# 40

# %% [markdown]
# ### Page 10 Loop

# %%
for i in soup9:
    address9 = soup9.find_all (class_= 'list-card-addr')
    price9 = list(soup9.find_all (class_='list-card-price'))
    details9 = list(soup9.find_all("ul", class_="list-card-details"))
            

df9['prices'] = price9
df9['address'] = address9
df9['details'] = details9


urls = []

for link in soup9.find_all("article"):
    href = link.find('a',class_="list-card-link")
    addresses = href.find('address')
    addresses.extract()
    urls.append(href)

# %%
# Import the urls into a column called links
df9['links'] = urls
df9['links'] = df9['links'].astype('str')

# %%
len(df9)
# Out:
# 40

# %% [markdown]
# ### Page 11 Loop

# %%
for i in soup10:
    address10 = soup10.find_all (class_= 'list-card-addr')
    price10 = list(soup10.find_all (class_='list-card-price'))
    details10 = list(soup10.find_all("ul", class_="list-card-details"))
            

df10['prices'] = price10
df10['address'] = address10
df10['details'] = details10


urls = []

for link in soup10.find_all("article"):
    href = link.find('a',class_="list-card-link")
    addresses = href.find('address')
    addresses.extract()
    urls.append(href)

# %%
# Import the urls into a column called links
df10['links'] = urls
df10['links'] = df10['links'].astype('str')

# %%
len(df10)
# Out:
# 40

# %% [markdown]
# ### Page 12 Loop

# %%
for i in soup11:
    address11 = soup11.find_all (class_= 'list-card-addr')
    price11 = list(soup11.find_all (class_='list-card-price'))
    details11 = list(soup11.find_all("ul", class_="list-card-details"))
            

df11['prices'] = price11
df11['address'] = address11
df11['details'] = details11


urls = []

for link in soup11.find_all("article"):
    href = link.find('a',class_="list-card-link")
    addresses = href.find('address')
    addresses.extract()
    urls.append(href)

# %%
# Import the urls into a column called links
df11['links'] = urls
df11['links'] = df11['links'].astype('str')

# %%
len(df11)
# Out:
# 40

# %% [markdown]
# ### Page 13 Loop

# %%
for i in soup12:
    address12 = soup12.find_all (class_= 'list-card-addr')
    price12 = list(soup12.find_all (class_='list-card-price'))
    details12 = list(soup12.find_all("ul", class_="list-card-details"))
            

df12['prices'] = price12
df12['address'] = address12
df12['details'] = details12


urls = []

for link in soup12.find_all("article"):
    href = link.find('a',class_="list-card-link")
    addresses = href.find('address')
    addresses.extract()
    urls.append(href)

# %%
# Import the urls into a column called links
df12['links'] = urls
df12['links'] = df12['links'].astype('str')

# %%
len(df12)
# Out:
# 40

# %% [markdown]
# ### Page 14 Loop

# %%
for i in soup13:
    address13 = soup13.find_all (class_= 'list-card-addr')
    price13 = list(soup13.find_all (class_='list-card-price'))
    details13 = list(soup13.find_all("ul", class_="list-card-details"))
            

df13['prices'] = price13
df13['address'] = address13
df13['details'] = details13


urls = []

for link in soup13.find_all("article"):
    href = link.find('a',class_="list-card-link")
    addresses = href.find('address')
    addresses.extract()
    urls.append(href)

# %%
# Import the urls into a column called links
df13['links'] = urls
df13['links'] = df13['links'].astype('str')

# %%
len(df13)
# Out:
# 40

# %% [markdown]
# ### Page 15 Loop

# %%
for i in soup14:
    address14 = soup14.find_all (class_= 'list-card-addr')
    price14 = list(soup14.find_all (class_='list-card-price'))
    details14 = list(soup14.find_all("ul", class_="list-card-details"))
            

df14['prices'] = price14
df14['address'] = address14
df14['details'] = details14


urls = []

for link in soup14.find_all("article"):
    href = link.find('a',class_="list-card-link")
    addresses = href.find('address')
    addresses.extract()
    urls.append(href)

# %%
# Import the urls into a column called links
df14['links'] = urls
df14['links'] = df14['links'].astype('str')

# %%
len(df14)
# Out:
# 40

# %% [markdown]
# ### Now that all 15 pages have been looped and scraped, we can now append all dataframes for this state together into one dataframe
# *Note: The first and second dataframes have already been appended from above. So we start by appending df2

# %%
# Now append all dataframes together
df = df.append(df2, ignore_index = True) 
df = df.append(df3, ignore_index = True) 
df = df.append(df4, ignore_index = True) 
df = df.append(df5, ignore_index = True) 
df = df.append(df6, ignore_index = True) 
df = df.append(df7, ignore_index = True) 
df = df.append(df8, ignore_index = True) 
df = df.append(df9, ignore_index = True)
df = df.append(df10, ignore_index = True)
df = df.append(df11, ignore_index = True)
df = df.append(df12, ignore_index = True)
df = df.append(df13, ignore_index = True)
df = df.append(df14, ignore_index = True)

# %%
# See length of dataframe
len(df)
# Out:
# 600

# %%
# Lets look at first 50 rows
df.head(50)
# Out:
#         prices                                           address  \
# 0   [$322,500]            [13495 Wildridge Dr, Wamego, KS 66547]
# 1   [$499,000]         [4020 W 96th St, Overland Park, KS 66207]
# 2     [$5,000]                 [1414 Main St, Jetmore, KS 67854]
# 3   [$179,000]             [8932 W 17th St N, Wichita, KS 67212]
# 4   [$129,500]                [120 S 1st St, Sterling, KS 67579]
# 5   [$175,000]               [1211 N 1st Ave, Mulvane, KS 67110]
# 6   [$189,900]        [1013 N Ridge Way Rd, Rose Hill, KS 67133]
# 7   [$199,000]          [205 Cedarlane Dr, Wellsville, KS 66092]
# 8   [$195,000]       [2567 Peter Pan Rd, Independence, KS 67301]
# 9   [$285,000]              [2640 Indiana Ter, Ottawa, KS 66067]
# 10  [$250,000]                [9348 Mullen Rd, Lenexa, KS 66215]
# 11  [$120,000]             [602 Meadow Ln, Fort Scott, KS 66701]
# 12  [$455,000]          [27535 Normandy Rd, Louisburg, KS 66053]
# 13  [$215,000]          [1215 S Chestnut St, Halstead, KS 67056]
# 14  [$198,900]         [2614 Belle Crest Dr, Lawrence, KS 66046]
# 15  [$198,500]            [1716 Mikes Dr, Garden City, KS 67846]
# 16   [$19,000]                 [310 W North St, Sedan, KS 67361]
# 17  [$210,000]            [1975 Us Highway 166, Caney, KS 67333]
# 18   [$39,900]                 [214 N Poplar St, Hope, KS 67451]
# 19  [$155,000]          [902 S Atchison St, El Dorado, KS 67042]
# 20  [$247,500]              [1676 SW 90th St, Augusta, KS 67010]
# 21  [$225,000]           [2325 Atchison Ave, Lawrence, KS 66047]
# 22  [$265,000]               [5731 Walmer St, Mission, KS 66202]
# 23  [$345,000]            [3405 S 159th St E, Wichita, KS 67232]
# 24  [$379,000]             [15420 Belmont Ct, Basehor, KS 66007]
# 25  [$120,000]            [503 S Palmberg St, Meriden, KS 66512]
# 26  [$219,000]               [1117 Julia St, Atchison, KS 66002]
# 27  [$128,000]  [17387 N Munkers Creek Rd, Alta Vista, KS 66834]
# 28  [$125,000]            [605 Thurston St, Manhattan, KS 66502]
# 29  [$185,000]              [1156 N Henry St, Augusta, KS 67010]
# 30  [$195,000]        [30504 W Harry St, Garden Plain, KS 67050]
# 31  [$235,000]              [11806 W Taft Ct, Wichita, KS 67209]
# 32  [$164,900]           [2051 N 42nd St, Kansas City, KS 66104]
# 33  [$155,000]            [930 N 84th Dr, Kansas City, KS 66112]
# 34  [$170,000]           [8 N Ridge Way Rd, Rose Hill, KS 67133]
# 35  [$285,000]     [7312 Cherokee Dr, Prairie Village, KS 66208]
# 36  [$190,000]        [2517 N Pine Grove Cir, Wichita, KS 67205]
# 37  [$165,000]         [712 Leavenworth St, Manhattan, KS 66502]
# 38  [$165,000]     [2420 Washington Blvd, Kansas City, KS 66102]
# 39  [$135,000]                [309 E Main St, Augusta, KS 67010]
# 40  [$499,000]          [10529 King St, Overland Park, KS 66214]
# 41  [$395,000]          [9330 S Stearns St, Haysville, KS 67060]
# 42  [$195,000]         [2519 Belle Haven Dr, Lawrence, KS 66046]
# 43  [$539,900]              [5832 Granada Ln, Fairway, KS 66205]
# 44   [$25,000]               [507 W 9th St, Pittsburg, KS 66762]
# 45   [$35,000]        [1617 N Michigan Ave, Pittsburg, KS 66762]
# 46   [$39,900]             [602 S Ninnescah St, Pratt, KS 67124]
# 47  [$295,000]               [1965 Avenue V, Sterling, KS 67579]
# 48  [$185,000]             [11635 N K92 Hwy, Mc Louth, KS 66054]
# 49  [$249,900]              [525 N Poplar St, Gardner, KS 66030]
#
#                                               details  \
# 0   [[4, [ ,  , bds]], [3, [ ,  , ba]], [2,164, [ ...
# 1   [[3, [ ,  , bds]], [4, [ ,  , ba]], [3,444, [ ...
# 2   [[2, [ ,  , bds]], [2, [ ,  , ba]], [1,171, [ ...
# 3   [[3, [ ,  , bds]], [2, [ ,  , ba]], [2,556, [ ...
# 4   [[4, [ ,  , bds]], [1, [ ,  , ba]], [1,381, [ ...
# 5   [[4, [ ,  , bds]], [2, [ ,  , ba]], [1,530, [ ...
# 6   [[4, [ ,  , bds]], [4, [ ,  , ba]], [1,991, [ ...
# 7   [[3, [ ,  , bds]], [2, [ ,  , ba]], [1,344, [ ...
# 8   [[3, [ ,  , bds]], [2, [ ,  , ba]], [2,036, [ ...
# 9   [[3, [ ,  , bds]], [2, [ ,  , ba]], [2,486, [ ...
# 10  [[4, [ ,  , bds]], [2, [ ,  , ba]], [2,634, [ ...
# 11  [[5, [ ,  , bds]], [2, [ ,  , ba]], [2,116, [ ...
# 12  [[4, [ ,  , bds]], [3, [ ,  , ba]], [2,950, [ ...
# 13  [[3, [ ,  , bds]], [3, [ ,  , ba]], [2,176, [ ...
# 14  [[4, [ ,  , bds]], [2, [ ,  , ba]], [1,840, [ ...
# 15  [[3, [ ,  , bds]], [2, [ ,  , ba]], [1,040, [ ...
# 16  [[2, [ ,  , bds]], [1, [ ,  , ba]], [1,224, [ ...
# 17  [[3, [ ,  , bds]], [2, [ ,  , ba]], [1,734, [ ...
# 18  [[3, [ ,  , bds]], [1, [ ,  , ba]], [1,490, [ ...
# 19  [[3, [ ,  , bds]], [2, [ ,  , ba]], [2,152, [ ...
# 20  [[6, [ ,  , bds]], [4, [ ,  , ba]], [3,305, [ ...
# 21  [[3, [ ,  , bds]], [2, [ ,  , ba]], [1,380, [ ...
# 22  [[3, [ ,  , bds]], [2, [ ,  , ba]], [3,264, [ ...
# 23  [[3, [ ,  , bds]], [2, [ ,  , ba]], [3,236, [ ...
# 24  [[4, [ ,  , bds]], [3, [ ,  , ba]], [2,823, [ ...
# 25  [[3, [ ,  , bds]], [1, [ ,  , ba]], [1,278, [ ...
# 26  [[3, [ ,  , bds]], [3, [ ,  , ba]], [2,852, [ ...
# 27  [[3, [ ,  , bds]], [2, [ ,  , ba]], [1,918, [ ...
# 28  [[5, [ ,  , bds]], [4, [ ,  , ba]], [2,488, [ ...
# 29  [[3, [ ,  , bds]], [3, [ ,  , ba]], [3,637, [ ...
# 30  [[3, [ ,  , bds]], [4, [ ,  , ba]], [2,781, [ ...
# 31  [[4, [ ,  , bds]], [3, [ ,  , ba]], [2,378, [ ...
# 32  [[3, [ ,  , bds]], [2, [ ,  , ba]], [2,304, [ ...
# 33  [[4, [ ,  , bds]], [2, [ ,  , ba]], [1,515, [ ...
# 34  [[3, [ ,  , bds]], [2, [ ,  , ba]], [1,566, [ ...
# 35  [[2, [ ,  , bds]], [2, [ ,  , ba]], [1,460, [ ...
# 36  [[6, [ ,  , bds]], [3, [ ,  , ba]], [2,328, [ ...
# 37  [[5, [ ,  , bds]], [2, [ ,  , ba]], [1,848, [ ...
# 38  [[3, [ ,  , bds]], [3, [ ,  , ba]], [2,132, [ ...
# 39  [[3, [ ,  , bds]], [2, [ ,  , ba]], [1,054, [ ...
# 40  [[4, [ ,  , bds]], [3, [ ,  , ba]], [2,164, [ ...
# 41  [[3, [ ,  , bds]], [4, [ ,  , ba]], [3,444, [ ...
# 42  [[2, [ ,  , bds]], [2, [ ,  , ba]], [1,171, [ ...
# 43  [[3, [ ,  , bds]], [2, [ ,  , ba]], [2,556, [ ...
# 44  [[4, [ ,  , bds]], [1, [ ,  , ba]], [1,381, [ ...
# 45  [[4, [ ,  , bds]], [2, [ ,  , ba]], [1,530, [ ...
# 46  [[4, [ ,  , bds]], [4, [ ,  , ba]], [1,991, [ ...
# 47  [[3, [ ,  , bds]], [2, [ ,  , ba]], [1,344, [ ...
# 48  [[3, [ ,  , bds]], [2, [ ,  , ba]], [2,036, [ ...
# 49  [[3, [ ,  , bds]], [2, [ ,  , ba]], [2,486, [ ...
#
#                                                 links
# 0   <a class="list-card-link list-card-link-top-ma...
# 1   <a class="list-card-link list-card-link-top-ma...
# 2   <a class="list-card-link list-card-link-top-ma...
# 3   <a class="list-card-link list-card-link-top-ma...
# 4   <a class="list-card-link list-card-link-top-ma...
# 5   <a class="list-card-link list-card-link-top-ma...
# 6   <a class="list-card-link list-card-link-top-ma...
# 7   <a class="list-card-link list-card-link-top-ma...
# 8   <a class="list-card-link list-card-link-top-ma...
# 9   <a class="list-card-link list-card-link-top-ma...
# 10  <a class="list-card-link list-card-link-top-ma...
# 11  <a class="list-card-link list-card-link-top-ma...
# 12  <a class="list-card-link list-card-link-top-ma...
# 13  <a class="list-card-link list-card-link-top-ma...
# 14  <a class="list-card-link list-card-link-top-ma...
# 15  <a class="list-card-link list-card-link-top-ma...
# 16  <a class="list-card-link list-card-link-top-ma...
# 17  <a class="list-card-link list-card-link-top-ma...
# 18  <a class="list-card-link list-card-link-top-ma...
# 19  <a class="list-card-link list-card-link-top-ma...
# 20  <a class="list-card-link list-card-link-top-ma...
# 21  <a class="list-card-link list-card-link-top-ma...
# 22  <a class="list-card-link list-card-link-top-ma...
# 23  <a class="list-card-link list-card-link-top-ma...
# 24  <a class="list-card-link list-card-link-top-ma...
# 25  <a class="list-card-link list-card-link-top-ma...
# 26  <a class="list-card-link list-card-link-top-ma...
# 27  <a class="list-card-link list-card-link-top-ma...
# 28  <a class="list-card-link list-card-link-top-ma...
# 29  <a class="list-card-link list-card-link-top-ma...
# 30  <a class="list-card-link list-card-link-top-ma...
# 31  <a class="list-card-link list-card-link-top-ma...
# 32  <a class="list-card-link list-card-link-top-ma...
# 33  <a class="list-card-link list-card-link-top-ma...
# 34  <a class="list-card-link list-card-link-top-ma...
# 35  <a class="list-card-link list-card-link-top-ma...
# 36  <a class="list-card-link list-card-link-top-ma...
# 37  <a class="list-card-link list-card-link-top-ma...
# 38  <a class="list-card-link list-card-link-top-ma...
# 39  <a class="list-card-link list-card-link-top-ma...
# 40  <a class="list-card-link list-card-link-top-ma...
# 41  <a class="list-card-link list-card-link-top-ma...
# 42  <a class="list-card-link list-card-link-top-ma...
# 43  <a class="list-card-link list-card-link-top-ma...
# 44  <a class="list-card-link list-card-link-top-ma...
# 45  <a class="list-card-link list-card-link-top-ma...
# 46  <a class="list-card-link list-card-link-top-ma...
# 47  <a class="list-card-link list-card-link-top-ma...
# 48  <a class="list-card-link list-card-link-top-ma...
# 49  <a class="list-card-link list-card-link-top-ma...

# %% [markdown]
# # Data Cleaning
# #### Now that we have the scraped Zillow data for this state, we need to clean this data up a bit for better analysis later on and easier handling in the Power BI dashboard

# %%
# Rearange columns a bit
df = df[['prices', 'address', 'links', 'details']]

# %%
# Convert columns to string
df['prices'] = df['prices'].astype('str')
df['address'] = df['address'].astype('str')
df['details'] = df['details'].astype('str')

# %%
# Show top 5 rows
df.head()
# Out:
#                                               prices  \
# 0  <div aria-label="$322,500" class="list-card-pr...
# 1  <div aria-label="$499,000" class="list-card-pr...
# 2  <div aria-label="$5,000" class="list-card-pric...
# 3  <div aria-label="$179,000" class="list-card-pr...
# 4  <div aria-label="$129,500" class="list-card-pr...
#
#                                              address  \
# 0  <address class="list-card-addr">13495 Wildridg...
# 1  <address class="list-card-addr">4020 W 96th St...
# 2  <address class="list-card-addr">1414 Main St, ...
# 3  <address class="list-card-addr">8932 W 17th St...
# 4  <address class="list-card-addr">120 S 1st St, ...
#
#                                                links  \
# 0  <a class="list-card-link list-card-link-top-ma...
# 1  <a class="list-card-link list-card-link-top-ma...
# 2  <a class="list-card-link list-card-link-top-ma...
# 3  <a class="list-card-link list-card-link-top-ma...
# 4  <a class="list-card-link list-card-link-top-ma...
#
#                                              details
# 0  <ul class="list-card-details"><li class="">4<a...
# 1  <ul class="list-card-details"><li class="">3<a...
# 2  <ul class="list-card-details"><li class="">2<a...
# 3  <ul class="list-card-details"><li class="">3<a...
# 4  <ul class="list-card-details"><li class="">4<a...

# %% [markdown]
# ### Clean Prices Column
# - HTML needs to be removed
# - Listing prices are collected twice and needs to only show once

# %%
# Keep only last 20 characters to remove some unwanted string characters and 2nd price reocurrence
df['prices'] = df['prices'].str[-20:]
df.head()
# Out:
#                  prices                                            address  \
# 0  rice">$322,500</div>  <address class="list-card-addr">13495 Wildridg...
# 1  rice">$499,000</div>  <address class="list-card-addr">4020 W 96th St...
# 2  -price">$5,000</div>  <address class="list-card-addr">1414 Main St, ...
# 3  rice">$179,000</div>  <address class="list-card-addr">8932 W 17th St...
# 4  rice">$129,500</div>  <address class="list-card-addr">120 S 1st St, ...
#
#                                                links  \
# 0  <a class="list-card-link list-card-link-top-ma...
# 1  <a class="list-card-link list-card-link-top-ma...
# 2  <a class="list-card-link list-card-link-top-ma...
# 3  <a class="list-card-link list-card-link-top-ma...
# 4  <a class="list-card-link list-card-link-top-ma...
#
#                                              details
# 0  <ul class="list-card-details"><li class="">4<a...
# 1  <ul class="list-card-details"><li class="">3<a...
# 2  <ul class="list-card-details"><li class="">2<a...
# 3  <ul class="list-card-details"><li class="">3<a...
# 4  <ul class="list-card-details"><li class="">4<a...

# %%
# Extract and keep 1 listing price as dollar amount 
df['prices'] = df['prices'].str.extract('(\$[0-9,.]+)')
df.head()
# Out:
#      prices                                            address  \
# 0  $322,500  <address class="list-card-addr">13495 Wildridg...
# 1  $499,000  <address class="list-card-addr">4020 W 96th St...
# 2    $5,000  <address class="list-card-addr">1414 Main St, ...
# 3  $179,000  <address class="list-card-addr">8932 W 17th St...
# 4  $129,500  <address class="list-card-addr">120 S 1st St, ...
#
#                                                links  \
# 0  <a class="list-card-link list-card-link-top-ma...
# 1  <a class="list-card-link list-card-link-top-ma...
# 2  <a class="list-card-link list-card-link-top-ma...
# 3  <a class="list-card-link list-card-link-top-ma...
# 4  <a class="list-card-link list-card-link-top-ma...
#
#                                              details
# 0  <ul class="list-card-details"><li class="">4<a...
# 1  <ul class="list-card-details"><li class="">3<a...
# 2  <ul class="list-card-details"><li class="">2<a...
# 3  <ul class="list-card-details"><li class="">3<a...
# 4  <ul class="list-card-details"><li class="">4<a...

# %% [markdown]
# ### Clean Address Column
# - HTML needs to be removed

# %%
# Remove all html tags from address
df['address'] = df['address'].replace('<address class="list-card-addr">', ' ', regex=True)
df['address'] = df['address'].replace('</address>', ' ', regex=True)
df.head()
# Out:
#      prices                                    address  \
# 0  $322,500      13495 Wildridge Dr, Wamego, KS 66547
# 1  $499,000   4020 W 96th St, Overland Park, KS 66207
# 2    $5,000           1414 Main St, Jetmore, KS 67854
# 3  $179,000       8932 W 17th St N, Wichita, KS 67212
# 4  $129,500          120 S 1st St, Sterling, KS 67579
#
#                                                links  \
# 0  <a class="list-card-link list-card-link-top-ma...
# 1  <a class="list-card-link list-card-link-top-ma...
# 2  <a class="list-card-link list-card-link-top-ma...
# 3  <a class="list-card-link list-card-link-top-ma...
# 4  <a class="list-card-link list-card-link-top-ma...
#
#                                              details
# 0  <ul class="list-card-details"><li class="">4<a...
# 1  <ul class="list-card-details"><li class="">3<a...
# 2  <ul class="list-card-details"><li class="">2<a...
# 3  <ul class="list-card-details"><li class="">3<a...
# 4  <ul class="list-card-details"><li class="">4<a...

# %% [markdown]
# ### Clean Links Column
# - HTML needs to be removed

# %%
# Remove all html tags from links
df['links'] = df['links'].replace('<a class="list-card-link list-card-link-top-margin" href="', ' ', regex=True)
df['links'] = df['links'].replace('" tabindex="0"></a>', ' ', regex=True)
df.head()
# Out:
#      prices                                    address  \
# 0  $322,500      13495 Wildridge Dr, Wamego, KS 66547
# 1  $499,000   4020 W 96th St, Overland Park, KS 66207
# 2    $5,000           1414 Main St, Jetmore, KS 67854
# 3  $179,000       8932 W 17th St N, Wichita, KS 67212
# 4  $129,500          120 S 1st St, Sterling, KS 67579
#
#                                                links  \
# 0   https://www.zillow.com/homedetails/13495-Wild...
# 1   https://www.zillow.com/homedetails/4020-W-96t...
# 2   https://www.zillow.com/homedetails/1414-Main-...
# 3   https://www.zillow.com/homedetails/8932-W-17t...
# 4   https://www.zillow.com/homedetails/120-S-1st-...
#
#                                              details
# 0  <ul class="list-card-details"><li class="">4<a...
# 1  <ul class="list-card-details"><li class="">3<a...
# 2  <ul class="list-card-details"><li class="">2<a...
# 3  <ul class="list-card-details"><li class="">3<a...
# 4  <ul class="list-card-details"><li class="">4<a...

# %% [markdown]
# ### Clean Details Column
# - HTML needs to be removed
# - Beds, Baths, and SQFT need to be seperated into seperate columns

# %%
# Remove all characters from each value of details except numbers and commas
def find_number(text):
    num = re.findall(r'[0-9,]+',text)
    return " ".join(num)
df['details']=df['details'].apply(lambda x: find_number(x))

# %%
# Trim any leading and trailing white spaces from the details column to avoid errors when splitting
df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
df.head()
# Out:
#      prices                                  address  \
# 0  $322,500     13495 Wildridge Dr, Wamego, KS 66547
# 1  $499,000  4020 W 96th St, Overland Park, KS 66207
# 2    $5,000          1414 Main St, Jetmore, KS 67854
# 3  $179,000      8932 W 17th St N, Wichita, KS 67212
# 4  $129,500         120 S 1st St, Sterling, KS 67579
#
#                                                links    details
# 0  https://www.zillow.com/homedetails/13495-Wildr...  4 3 2,164
# 1  https://www.zillow.com/homedetails/4020-W-96th...  3 4 3,444
# 2  https://www.zillow.com/homedetails/1414-Main-S...  2 2 1,171
# 3  https://www.zillow.com/homedetails/8932-W-17th...  3 2 2,556
# 4  https://www.zillow.com/homedetails/120-S-1st-S...  4 1 1,381

# %%
# Split details column into 3 new columns beds, baths, sqft
df['beds'] = df.details.str.split(' ', expand = True)[0]
df['baths'] = df.details.str.split(' ', expand = True)[1]
df['sqft'] = df.details.str.split(' ', expand = True)[2]

# %%
# Show top 5 rows
df.head()
# Out:
#      prices                                  address  \
# 0  $322,500     13495 Wildridge Dr, Wamego, KS 66547
# 1  $499,000  4020 W 96th St, Overland Park, KS 66207
# 2    $5,000          1414 Main St, Jetmore, KS 67854
# 3  $179,000      8932 W 17th St N, Wichita, KS 67212
# 4  $129,500         120 S 1st St, Sterling, KS 67579
#
#                                                links    details beds baths  \
# 0  https://www.zillow.com/homedetails/13495-Wildr...  4 3 2,164    4     3
# 1  https://www.zillow.com/homedetails/4020-W-96th...  3 4 3,444    3     4
# 2  https://www.zillow.com/homedetails/1414-Main-S...  2 2 1,171    2     2
# 3  https://www.zillow.com/homedetails/8932-W-17th...  3 2 2,556    3     2
# 4  https://www.zillow.com/homedetails/120-S-1st-S...  4 1 1,381    4     1
#
#     sqft
# 0  2,164
# 1  3,444
# 2  1,171
# 3  2,556
# 4  1,381

# %%
# Remove commas from sqft and convert to float
df["sqft"] = df["sqft"].str.replace(",","").astype(float)

# %%
# Remove $ from prices column and remove commas
df['prices'] = df['prices'].str.replace('$', '')
df['prices'] = df['prices'].str.replace(',', '')

# %%
#convert prices column to float
df['prices'] = df['prices'].astype('float')

# %%
df.head()
# Out:
#      prices                                  address  \
# 0  322500.0     13495 Wildridge Dr, Wamego, KS 66547
# 1  499000.0  4020 W 96th St, Overland Park, KS 66207
# 2    5000.0          1414 Main St, Jetmore, KS 67854
# 3  179000.0      8932 W 17th St N, Wichita, KS 67212
# 4  129500.0         120 S 1st St, Sterling, KS 67579
#
#                                                links    details beds baths  \
# 0  https://www.zillow.com/homedetails/13495-Wildr...  4 3 2,164    4     3
# 1  https://www.zillow.com/homedetails/4020-W-96th...  3 4 3,444    3     4
# 2  https://www.zillow.com/homedetails/1414-Main-S...  2 2 1,171    2     2
# 3  https://www.zillow.com/homedetails/8932-W-17th...  3 2 2,556    3     2
# 4  https://www.zillow.com/homedetails/120-S-1st-S...  4 1 1,381    4     1
#
#      sqft
# 0  2164.0
# 1  3444.0
# 2  1171.0
# 3  2556.0
# 4  1381.0

# %% [markdown]
# ## Extract City and State from Address Column

# %%
# Split address column into street, city, and statezip
df[['street','city','statezip']] = df.address.str.split(',',expand=True)

# %%
# Show top 2 rows
df.head(2)
# Out:
#      prices                                  address  \
# 0  322500.0     13495 Wildridge Dr, Wamego, KS 66547
# 1  499000.0  4020 W 96th St, Overland Park, KS 66207
#
#                                                links    details beds baths  \
# 0  https://www.zillow.com/homedetails/13495-Wildr...  4 3 2,164    4     3
# 1  https://www.zillow.com/homedetails/4020-W-96th...  3 4 3,444    3     4
#
#      sqft              street            city   statezip
# 0  2164.0  13495 Wildridge Dr          Wamego   KS 66547
# 1  3444.0      4020 W 96th St   Overland Park   KS 66207

# %%
# Trim any leading and trailing spaces from statezip column to avoid errors while splitting zip column
df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# %%
# Split statezip column into  new columns state and zip
df['state'] = df.statezip.str.split(' ', expand = True)[0]
df['zip'] = df.statezip.str.split(' ', expand = True)[1]

# %%
# Show top 2 rows
df.head(2)
# Out:
#      prices                                  address  \
# 0  322500.0     13495 Wildridge Dr, Wamego, KS 66547
# 1  499000.0  4020 W 96th St, Overland Park, KS 66207
#
#                                                links    details beds baths  \
# 0  https://www.zillow.com/homedetails/13495-Wildr...  4 3 2,164    4     3
# 1  https://www.zillow.com/homedetails/4020-W-96th...  3 4 3,444    3     4
#
#      sqft              street           city  statezip state    zip
# 0  2164.0  13495 Wildridge Dr         Wamego  KS 66547    KS  66547
# 1  3444.0      4020 W 96th St  Overland Park  KS 66207    KS  66207

# %%
# Now drop unwanted columns (details and statezip)
df = df.drop('details', 1)
df = df.drop('statezip', 1)
df.head()
# Out:
#      prices                                  address  \
# 0  322500.0     13495 Wildridge Dr, Wamego, KS 66547
# 1  499000.0  4020 W 96th St, Overland Park, KS 66207
# 2    5000.0          1414 Main St, Jetmore, KS 67854
# 3  179000.0      8932 W 17th St N, Wichita, KS 67212
# 4  129500.0         120 S 1st St, Sterling, KS 67579
#
#                                                links beds baths    sqft  \
# 0  https://www.zillow.com/homedetails/13495-Wildr...    4     3  2164.0
# 1  https://www.zillow.com/homedetails/4020-W-96th...    3     4  3444.0
# 2  https://www.zillow.com/homedetails/1414-Main-S...    2     2  1171.0
# 3  https://www.zillow.com/homedetails/8932-W-17th...    3     2  2556.0
# 4  https://www.zillow.com/homedetails/120-S-1st-S...    4     1  1381.0
#
#                street           city state    zip
# 0  13495 Wildridge Dr         Wamego    KS  66547
# 1      4020 W 96th St  Overland Park    KS  66207
# 2        1414 Main St        Jetmore    KS  67854
# 3    8932 W 17th St N        Wichita    KS  67212
# 4        120 S 1st St       Sterling    KS  67579

# %% [markdown]
# ### Look at full dataframe for scraped state
# ** Only run if full appended dataframe for state needs to be seen

# %%
# Print full dataframe for the scraped state
#df
# Out:
#         prices                                           address  \
# 0     322500.0              13495 Wildridge Dr, Wamego, KS 66547
# 1     499000.0           4020 W 96th St, Overland Park, KS 66207
# 2       5000.0                   1414 Main St, Jetmore, KS 67854
# 3     179000.0               8932 W 17th St N, Wichita, KS 67212
# 4     129500.0                  120 S 1st St, Sterling, KS 67579
# 5     175000.0                 1211 N 1st Ave, Mulvane, KS 67110
# 6     189900.0          1013 N Ridge Way Rd, Rose Hill, KS 67133
# 7     199000.0            205 Cedarlane Dr, Wellsville, KS 66092
# 8     195000.0         2567 Peter Pan Rd, Independence, KS 67301
# 9     285000.0                2640 Indiana Ter, Ottawa, KS 66067
# 10    250000.0                  9348 Mullen Rd, Lenexa, KS 66215
# 11    120000.0               602 Meadow Ln, Fort Scott, KS 66701
# 12    455000.0            27535 Normandy Rd, Louisburg, KS 66053
# 554                710 E 9th Ave         Winfield    KS  67156
# 555         309 S Washington Ave             Iola    KS  66749
# 556              1731 Morgan Ave          Parsons    KS  67357
# 557            1623 SW Plass Ave           Topeka    KS  66604
# 558               2819 N 77th St      Kansas City    KS  66109
# 559           659 S Santa Fe Ave           Salina    KS  67401
# 560            108 E Hackney Ave   Medicine Lodge    KS  67104
# 561               1038 S 50th Dr      Kansas City    KS  66106
# 562          129 Rock Creek Loop          Lansing    KS  66043
# 563               448 S Garst St          Wichita    KS  67209
# 564                400 W 35th St             Hays    KS  67601
# 565                17500 Ober Rd         Randolph    KS  66554
# 566                106 N Vine St          Abilene    KS  67410
# 567            2144 Griffith Ter        Manhattan    KS  66502
# 568                    2905 E Rd           Beloit    KS  67420
# 569             2716 Stevens Ave          Parsons    KS  67357
# 570                 407 N 6th St           Seneca    KS  66538
# 571              14 Deer Run Ter       Mound City    KS  66056
# 572          116 E Cottonwood St     Independence    KS  67301
# 573            513 S Garfield St       Enterprise    KS  67441
# 574             6508 W 202nd Ter          Bucyrus    KS  66013
# 575                 315 N 8th St   Conway Springs    KS  67031
# 576                 321 E 1st St            Bison    KS  67520
# 577                 231 W 4th St    Junction City    KS  66441
# 578            708 N Mulberry St           Ottawa    KS  66067
# 579           1012 N Gatewood Ct          Wichita    KS  67206
# 580             5807 W 140th Ter    Overland Park    KS  66223
# 581          3408 S Illinois Ave          Wichita    KS  67217
# 582             1618 Bradley Ave    Junction City    KS  66441
# 583                 315 S 2nd St           Atwood    KS  67730
# 584          601 N Forestview Ct          Wichita    KS  67235
# 585          1166 N Ponderosa Rd     Belle Plaine    KS  67013
# 586                 514 E 3rd St     Smith Center    KS  66967
# 587              203 N Taylor St        El Dorado    KS  67042
# 588             1040 NW 108th St            Burns    KS  66840
# 589           506 W Jefferson St        Pittsburg    KS  66762
# 590         2602 N Pennington Rd       Hutchinson    KS  67502
# 591          742-50 National Ave       Fort Scott    KS  66701
# 592                 615 W 1st St    Junction City    KS  66441
# 593                 520 E 1st St       Cunningham    KS  67035
# 594                710 E 9th Ave         Winfield    KS  67156
# 595         309 S Washington Ave             Iola    KS  66749
# 596              1731 Morgan Ave          Parsons    KS  67357
# 597            1623 SW Plass Ave           Topeka    KS  66604
# 598               2819 N 77th St      Kansas City    KS  66109
# 599           659 S Santa Fe Ave           Salina    KS  67401

# %%
# Export this states dataframe to excel file
df.to_excel('StateData/washingtondc.xlsx', index = False)

# %% [markdown]
# # Part One Final Notes:

# %% [markdown]
# #### - The housing data has been scraped for all states. I will now take all saved/exported Excel files created for each states listings and append them all together into a master dataset.
#
# #### -The process for the appending step is shown in the Jupyter Notebook "*Combining All States Housing Data*"
#
# #### -The master dataset will be about 30,000 rows with about 600 houses scraped for each state
#
# #### -During initial data cleaning above, I did not clean or take into account the Zillow listings scraped that may have been listings for land, plots, etc. These listings scraped can cause inconsistent data such as showing a listing having 30 bedrooms when it is really 30 acres of land for sale.
#
# #### -To help keep consistent data and BI dashboard accuracy later on in the project, I will perform additional data cleaning/processing and remove any values of land/plots and any null values from the master dataset during the Exploratory Data Analysis step.
