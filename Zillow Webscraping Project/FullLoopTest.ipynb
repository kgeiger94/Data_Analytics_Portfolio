# %%
import os
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
import sys
import numpy as np
import pandas as pd
import regex as re
import requests
import lxml
from lxml.html.soupparser import fromstring
import prettify
import numbers
import htmltext

# %%
#set some display settings for notebooks
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
req_headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'en-US,en;q=0.8',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'
}

# %%
#create url variables for each zillow page
with requests.Session() as s:
    state = 'kansas/' #*****change this city to what you want!!!!*****
    
    url = 'https://www.zillow.com/homes/for_sale/'+state
    url2 = 'https://www.zillow.com/homes/for_sale/'+state+'/2_p/'
    url3 = 'https://www.zillow.com/homes/for_sale/'+state+'/3_p/'
    url4 = 'https://www.zillow.com/homes/for_sale/'+state+'/4_p/'
    url5 = 'https://www.zillow.com/homes/for_sale/'+state+'/5_p/'
    url6 = 'https://www.zillow.com/homes/for_sale/'+state+'/6_p/'
    url7 = 'https://www.zillow.com/homes/for_sale/'+state+'/7_p/'
    url8 = 'https://www.zillow.com/homes/for_sale/'+state+'/8_p/'
    url9 = 'https://www.zillow.com/homes/for_sale/'+state+'/9_p/'
    url10 = 'https://www.zillow.com/homes/for_sale/'+state+'/10_p/'

    r = s.get(url, headers=req_headers)
    r2 = s.get(url2, headers=req_headers)
    r3 = s.get(url3, headers=req_headers)
    r4 = s.get(url4, headers=req_headers)
    r5 = s.get(url5, headers=req_headers)
    r6 = s.get(url6, headers=req_headers)
    r7 = s.get(url7, headers=req_headers)
    r8 = s.get(url8, headers=req_headers)
    r9 = s.get(url9, headers=req_headers)
    r10 = s.get(url10, headers=req_headers)
    
    url_links = [url, url2, url3, url4, url5, url6, url7, url8, url9, url10]

# %%
#url = 'https://www.zillow.com/homes/for_sale/'+city

# %%
#r = s.get(url, headers=req_headers)

# %%
#url_links = [url]

# %%
#add contents of urls to soup variable from each url
soup = BeautifulSoup(r.content, 'html.parser')
soup1 = BeautifulSoup(r2.content, 'html.parser')
soup2 = BeautifulSoup(r3.content, 'html.parser')
soup3 = BeautifulSoup(r4.content, 'html.parser')
soup4 = BeautifulSoup(r5.content, 'html.parser')
soup5 = BeautifulSoup(r6.content, 'html.parser')
soup6 = BeautifulSoup(r7.content, 'html.parser')
soup7 = BeautifulSoup(r8.content, 'html.parser')
soup8 = BeautifulSoup(r9.content, 'html.parser')
soup9 = BeautifulSoup(r10.content, 'html.parser')

# %%
#soup = BeautifulSoup(r.content, 'html.parser')

# %%
df = pd.DataFrame()
df1 = pd.DataFrame()

#all for loops are pulling the specified variable using beautiful soup and inserting into said variable
for i in soup:
    address = soup.find_all (class_= 'list-card-addr')
    price = list(soup.find_all (class_='list-card-price'))
    beds = list(soup.find_all("ul", class_="list-card-details"))
    details = soup.find_all ('div', {'class': 'list-card-details'})
    home_type = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link = soup.find_all (class_= 'list-card-link')
    
    
    
    
#create dataframe columns out of variables
df['prices'] = price
df['address'] = address
df['beds'] = beds




#create empty url list
urls = []
#loop through url, pull the href and strip out the address tag
for link in soup.find_all("article"):
    href = link.find('a',class_="list-card-link")
    addresses = href.find('address')
    addresses.extract()
    urls.append(href)

# %%
#import urls into a links column
df['links'] = urls
df['links'] = df['links'].astype('str')

# %%
#remove html tags from links
df['links'] = df['links'].replace('<a class="list-card-link list-card-link-top-margin" href="', ' ', regex=True)
df['links'] = df['links'].replace('" tabindex="0"></a>', ' ', regex=True)

# %% [markdown]
# ### Page 2 Loop

# %%
for i in soup1:
    address1 = soup1.find_all (class_= 'list-card-addr')
    price1 = list(soup1.find_all (class_='list-card-price'))
    beds1 = list(soup.find_all("ul", class_="list-card-details"))
    details1 = soup1.find_all ('div', {'class': 'list-card-details'})
    home_type1 = soup1.find_all ('div', {'class': 'list-card-footer'})
    last_updated1 = soup1.find_all ('div', {'class': 'list-card-top'})
    brokerage1 = list(soup1.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link1 = soup1.find_all (class_= 'list-card-link')

    
    
    
#create dataframe columns out of variables
df1['prices'] = price1
df1['address'] = address1
df1['beds'] = beds




#create empty url list
urls = []
#loop through url, pull the href and strip out the address tag
for link in soup1.find_all("article"):
    href = link.find('a',class_="list-card-link")
    addresses = href.find('address')
    addresses.extract()
    urls.append(href)

# %%
#import urls into a links column
df['links'] = urls
df['links'] = df['links'].astype('str')

# %%
#remove html tags from links
df['links'] = df['links'].replace('<a class="list-card-link list-card-link-top-margin" href="', ' ', regex=True)
df['links'] = df['links'].replace('" tabindex="0"></a>', ' ', regex=True)

# %%
#append first two dataframes
df = df.append(df1, ignore_index = True)

# %%
df
# Out:
#         prices                                        address                                               beds                                              links
# 0   [$225,000]             [1720 Road 54, Goodland, KS 67735]  [[4, [ ,  , bds]], [2, [ ,  , ba]], [1,824, [ ...   https://www.zillow.com/homedetails/4444-W-130...
# 1   [$120,000]             [804 Broad St, Winfield, KS 67156]  [[4, [ ,  , bds]], [2, [ ,  , ba]], [1,840, [ ...   https://www.zillow.com/homedetails/15610-W-14...
# 2     [$5,000]              [1414 Main St, Jetmore, KS 67854]  [[2, [ ,  , bds]], [2, [ ,  , ba]], [1,171, [ ...   https://www.zillow.com/homedetails/1322-21st-...
# 3   [$210,000]                [205 E 28th St, Hays, KS 67601]  [[4, [ ,  , bds]], [2, [ ,  , ba]], [2,242, [ ...   https://www.zillow.com/homedetails/1460-E-Sun...
# 4   [$180,000]         [7515 E 117th St, Overbrook, KS 66524]  [[3, [ ,  , bds]], [2, [ ,  , ba]], [1,080, [ ...   https://www.zillow.com/homedetails/2269-Quinc...
# 5    [$72,000]            [518 Delaware St, Jewell, KS 66949]  [[4, [ ,  , bds]], [2, [ ,  , ba]], [1,328, [ ...   https://www.zillow.com/homedetails/1313-Wilbr...
# 6    [$75,000]         [4721 Freeman Rd, Manhattan, KS 66503]  [[3, [ ,  , bds]], [2, [ ,  , ba]], [1,292, [ ...   https://www.zillow.com/homedetails/300-S-Kenn...
# 7    [$89,900]  [1018 N Washington Ave, Wellington, KS 67152]  [[3, [ ,  , bds]], [2, [ ,  , ba]], [1,772, [ ...   https://www.zillow.com/homedetails/2517-Reeve...
# 8   [$180,000]            [929 N Poplar St, Ottawa, KS 66067]  [[3, [ ,  , bds]], [2, [ ,  , ba]], [2,240, [ ...   https://www.zillow.com/homedetails/2517-N-Pin...
# 9   [$214,000]         [1801 Brown Ave, Osawatomie, KS 66064]  [[3, [ ,  , bds]], [1, [ ,  , ba]], [1,525, [ ...   https://www.zillow.com/homedetails/319-N-6th-...
# 10  [$106,000]            [502 N Chestnut St, Iola, KS 66749]  [[3, [ ,  , bds]], [2, [ ,  , ba]], [1
  [[4, [ ,  , bds]], [3, [ ,  , ba]], [2,421, [ ...                                                NaN
# 77  [$290,000]         [12525 S Lincoln St, Olathe, KS 66061]  [[4, [ ,  , bds]], [2, [ ,  , ba]], [2,041, [ ...                                                NaN
# 78  [$425,000]             [983 E 121st Pl, Olathe, KS 66061]  [[4, [ ,  , bds]], [2, [ ,  , ba]], [2,023, [ ...                                                NaN
# 79   [$19,900]             [804 S Grand Ave, Lyons, KS 67554]  [[4, [ ,  , bds]], [3, [ ,  , ba]], [2,971, [ ...                                                NaN

# %%
#change columns to string
df['prices'] = df['prices'].astype('str')
df['address'] = df['address'].astype('str')
df['beds'] = df['beds'].astype('str')

# %%
#remove html tags from address
df['address'] = df['address'].replace('<address class="list-card-addr">', ' ', regex=True)
df['address'] = df['address'].replace('</address>', ' ', regex=True)

# %%
df = df[['prices', 'address', 'links', 'beds']]
df.head()
# Out:
#                                               prices                                 address                                              links                                               beds
# 0  <div aria-label="$225,000" class="list-card-pr...       1720 Road 54, Goodland, KS 67735    https://www.zillow.com/homedetails/1720-Road-...  <ul class="list-card-details"><li class="">4<a...
# 1  <div aria-label="$120,000" class="list-card-pr...       804 Broad St, Winfield, KS 67156    https://www.zillow.com/homedetails/804-Broad-...  <ul class="list-card-details"><li class="">4<a...
# 2  <div aria-label="$5,000" class="list-card-pric...        1414 Main St, Jetmore, KS 67854    https://www.zillow.com/homedetails/1414-Main-...  <ul class="list-card-details"><li class="">2<a...
# 3  <div aria-label="$210,000" class="list-card-pr...          205 E 28th St, Hays, KS 67601    https://www.zillow.com/homedetails/205-E-28th...  <ul class="list-card-details"><li class="">4<a...
# 4  <div aria-label="$180,000" class="list-card-pr...   7515 E 117th St, Overbrook, KS 66524    https://www.zillow.com/homedetails/7515-E-117...  <ul class="list-card-details"><li class="">3<a...

# %%
#Keep only last 20 characters to remove some unwanted string characters and 2nd price reocurrence
df['prices'] = df['prices'].str[-20:]

# %%
#extract and keep dollar amount 
df['prices'] = df['prices'].str.extract('(\$[0-9,.]+)')

# %%
df = df[['prices', 'address', 'links', 'beds']]
df.head()
# Out:
#      prices                                 address                                              links                                               beds
# 0  $225,000       1720 Road 54, Goodland, KS 67735    https://www.zillow.com/homedetails/1720-Road-...  <ul class="list-card-details"><li class="">4<a...
# 1  $120,000       804 Broad St, Winfield, KS 67156    https://www.zillow.com/homedetails/804-Broad-...  <ul class="list-card-details"><li class="">4<a...
# 2    $5,000        1414 Main St, Jetmore, KS 67854    https://www.zillow.com/homedetails/1414-Main-...  <ul class="list-card-details"><li class="">2<a...
# 3  $210,000          205 E 28th St, Hays, KS 67601    https://www.zillow.com/homedetails/205-E-28th...  <ul class="list-card-details"><li class="">4<a...
# 4  $180,000   7515 E 117th St, Overbrook, KS 66524    https://www.zillow.com/homedetails/7515-E-117...  <ul class="list-card-details"><li class="">3<a...

# %%
#remove html and other unnecessary info from beds, ba, and sqft
df['beds'] = df['beds'].replace('<ul class="list-card-details"><li class="">', ' ', regex=True)

df['beds'] = df['beds'].replace('<abbr class="list-card-label"> <!-- -->bds</abbr></li><li class="">', ' ', regex=True)

df['beds'] = df['beds'].replace('<abbr class="list-card-label"> <!-- -->ba</abbr></li><li class="">', ' ', regex=True)

df['beds'] = df['beds'].replace('<abbr class="list-card-label"> <!-- -->bd</abbr></li><li class="">', ' ', regex=True)

df['beds'] = df['beds'].replace('<abbr class="list-card-label"> <!-- -->sqft</abbr></li><li class=', ' ', regex=True)

df['beds'] = df['beds'].replace('"list-card-statusText">- House for sale</li></ul>', ' ', regex=True)

# %%
df = pd.DataFrame(df.beds.str.split(' ',1).tolist(),
                                 columns = ['beds','baths'])

# %%
#rearrange the columns
df = df[['prices', 'address', 'links', 'beds']]
df
# Out:
#       prices                                        address                                              links            beds
# 0   $225,000              1720 Road 54, Goodland, KS 67735    https://www.zillow.com/homedetails/1720-Road-...     4 2 1,824
# 1   $120,000              804 Broad St, Winfield, KS 67156    https://www.zillow.com/homedetails/804-Broad-...     4 2 1,840
# 2     $5,000               1414 Main St, Jetmore, KS 67854    https://www.zillow.com/homedetails/1414-Main-...     2 2 1,171
# 3   $210,000                 205 E 28th St, Hays, KS 67601    https://www.zillow.com/homedetails/205-E-28th...     4 2 2,242
# 4   $180,000          7515 E 117th St, Overbrook, KS 66524    https://www.zillow.com/homedetails/7515-E-117...     3 2 1,080
# 5    $72,000             518 Delaware St, Jewell, KS 66949    https://www.zillow.com/homedetails/518-Delawa...     4 2 1,328
# 6    $75,000          4721 Freeman Rd, Manhattan, KS 66503    https://www.zillow.com/homedetails/4721-Freem...     3 2 1,292
# 7    $89,900   1018 N Washington Ave, Wellington, KS 67152    https://www.zillow.com/homedetails/1018-N-Was...     3 2 1,772
# 8   $180,000             929 N Poplar St, Ottawa, KS 66067    https://www.zillow.com/homedetails/929-N-Popl...     3 2 2,240
# 9   $214,000          1801 Brown Ave, Osawatomie, KS 66064    https://www.zillow.com/homedetails/1801-Brown...     3 1 1,525
# 10  $106,000             502 N Chestnut St, Iola, KS 66749    https://www.zillow.com/homedetails/502-N-Ches...     3 2 1,612
# 11  $179,900        111 W Rockwood Blvd, Mulvane, KS 67110    https://www.zillow.com/homedetails/111-W-Rock...     3 2 1,970
# 12  $238,000               4812 Cody St, Shawnee, KS 66203    https://www.zillow.com/homedetails/4812-Cody-...     3 2 1,760
# 13  $199,000             1111 N Main St, Kingman, KS 67068    https://www.zillow.com/homedetails/1111-N-Mai...   15 4 12,002
# 14  $179,000           8932 W 17th St N, Wichita, KS 67212    https://www.zillow.com/homedetails/8932-W-17t...     3 2 2,556
# 15  $322,500          13495 Wildridge Dr, Wamego, KS 66547    https://www.zillow.com/homedetails/13495-Wild...     4 3 2,164
# 16   $95,000         14 N Havana Lake Rd, Havana, KS 67347    https://www.zillow.com/homedetails/14-N-Havan...     2 1 1,096
# 17  $229,900            11406 W 68th St, Shawnee, KS 66203    https://www.zillow.com/homedetails/11406-W-68...     4 2 2,036
# 18  $219,900             2666 2660th Ln, Chapman, KS 67431    https://www.zillow.com/homedetails/2666-2660t...     4 2 2,020
# 19  $149,900        235 E 17th St, Junction City, KS 66441    https://www.zillow.com/homedetails/235-E-17th...     4 2 1,510
# 20  $151,000          736 E Marlin St, Mcpherson, KS 67460    https://www.zillow.com/homedetails/736-E-Marl...     3 2 1,684
# 21  $135,000             222 SE 44th Ter, Topeka, KS 66609    https://www.zillow.com/homedetails/222-SE-44t...     3 2 1,512
# 22  $225,000         2325 Atchison Ave, Lawrence, KS 66047    https://www.zillow.com/homedetails/2325-Atchi...     3 2 1,380
# 23  $289,900         2007 Roanoke Rd, Dodge City, KS 67801    https://www.zillow.com/homedetails/2007-Roano...     5 3 3,935
# 24  $149,900        2902 N Monroe St, Hutchinson, KS 67502    https://www.zillow.com/homedetails/2902-N-Mon...     2 4 1,731
# 25  $285,000    8925 Grandview Dr, Overland Park, KS 66212    https://www.zillow.com/homedetails/8925-Grand...     4 3 1,726
# 26   $89,000     120 W Spencer St, Saint Francis, KS 67756    https://www.zillow.com/homedetails/120-W-Spen...     2 1 1,464
# 27   $84,500          514 E 3rd St, Smith Center, KS 66967    https://www.zillow.com/homedetails/514-E-3rd-...     1 2 3,750
# 28  $295,000             1965 Avenue V, Sterling, KS 67579    https://www.zillow.com/homedetails/1965-Avenu...     3 3 2,563
# 29  $350,000   11300 Grandview Dr, Overland Park, KS 66210    https://www.zillow.com/homedetails/11300-Gran...     4 3 2,692
# 30  $218,500         12743 S Sycamore St, Olathe, KS 66062    https://www.zillow.com/homedetails/12743-S-Sy...     3 2 1,412
# 31  $435,000      8906 Birch Ln, Prairie Village, KS 66207    https://www.zillow.com/homedetails/8906-Birch...     4 3 2,168
# 32   $83,500              614 N High St, Mankato, KS 66956    https://www.zillow.com/homedetails/614-N-High...     5 4 3,262
# 33  $340,000          1402 S Ravenwood St, Derby, KS 67037    https://www.zillow.com/homedetails/1402-S-Rav...     5 3 3,133
# 34  $249,900            3012 Topeka Ln, Lawrence, KS 66047    https://www.zillow.com/homedetails/3012-Topek...     4 3 1,876
# 35  $385,000        601 N Forestview Ct, Wichita, KS 67235    https://www.zillow.com/homedetails/601-N-Fore...     5 3 4,429
# 36  $300,000           15635 S Apache St, Olathe, KS 66062    https://www.zillow.com/homedetails/15635-S-Ap...     4 3 2,421
# 37  $180,000             219 N Main St, Cimarron, KS 67835    https://www.zillow.com/homedetails/219-N-Main...     4 2 2,041
# 38  $205,000              113 Overlook Dr, Caney, KS 67333    https://www.zillow.com/homedetails/113-Overlo...     4 2 2,023
# 39  $310,000      10302 Caenen Dr, Overland Park, KS 66215    https://www.zillow.com/homedetails/10302-Caen...     4 3 2,971

# %%
df.to_excel('test6.xlsx', index = False)

# %% [raw]
# def find_number(text):
#     num = re.findall(r'[0-9]+',text)
#     return " ".join(num)
# df['beds']=df['beds'].apply(lambda x: find_number(x))
